# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.preprocessing import StandardScaler,MinMaxScaler
import optuna
from sklearn.svm import SVR
from sklearn.metrics import r2_score, mean_squared_error



model_data = pd.read_csv("../../przygotowanie_danych/model_data.csv")
X = model_data[["temperatura", "suma opadów", "wilgotność", "prędkość wiatru", "zachmurzenine", "day_number_in_year"]]
y = model_data['PM2.5']
model_data = model_data.iloc[1788:]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1,shuffle=False)
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


def objective(trial):
    kernel = trial.suggest_categorical('kernel', ['linear', 'poly', 'rbf', 'sigmoid'])
    C = trial.suggest_float('C', 0.1, 200.0)
    epsilon = trial.suggest_float('epsilon', 0.001, 0.5)
    degree = trial.suggest_int('degree', 1, 5)  
    
    coef0 = trial.suggest_float('coef0', -1.0, 1.0)

    model = SVR(kernel=kernel, C=C, epsilon=epsilon,degree=degree,coef0=coef0)

    model.fit(X_train_scaled, y_train)

    y_pred = model.predict(X_test_scaled)

    r2 = r2_score(y_test, y_pred)

    return r2

study = optuna.create_study(direction='maximize') 
stale_count = 0

best_r2 = -float('inf')

r2_values = []

for _ in range(11000):
    study.optimize(objective, n_trials=1)

    if study.best_value > best_r2:
        best_r2 = study.best_value
        stale_count = 0
    else:
        stale_count += 1

    r2_values.append(best_r2)

    if stale_count >= 1000 or best_r2 >= 1.0:
        break

best_params = study.best_params
best_r2 = study.best_value

print("Best Parameters:", best_params)



model = SVR(**best_params)
model.fit(X_train_scaled, y_train)
y_pred = model.predict(X_test_scaled)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Średni błąd kwadratowy (MSE): {mse}")
percent_match = r2 * 100
print(f"Procentowa zgodność: {percent_match:.2f}%")

y_test = y_test.reset_index(drop=True)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], 'r', label='y=x')
plt.scatter(y_test, y_pred)
for i in range(len(y_test)):
    plt.plot([y_test[i], y_test[i]], [y_test[i], y_pred[i]],'k--', lw=0.1)
plt.xlabel("Prawdziwe PM2.5")
plt.ylabel("Przewidziane PM2.5")
plt.title("Wykres porównania rzeczywistych i przewidywanych wartości PM2.5")
plt.show()

results = pd.DataFrame({'Rzeczywiste wartości (y_test)': y_test, 'Przewidywane wartości (y_pred)': y_pred})
results['Różnica'] = abs(results['Rzeczywiste wartości (y_test)'] - results['Przewidywane wartości (y_pred)'])
results.sort_values('Różnica')

model_data_test = pd.read_csv("../../przygotowanie_danych/model_data_test.csv")
model_data_test.index = pd.RangeIndex(start=3487, stop=3517, step=1)
model_data_test
X_test_test = model_data_test[["temperatura", "suma opadów", "wilgotność", "prędkość wiatru", "zachmurzenine", "day_number_in_year"]]
y_test_test = model_data_test['PM2.5']
X_test_test_scaled = scaler.transform(X_test_test)

y_pred_test = model.predict(X_test_test_scaled)
mse = mean_squared_error(y_test_test, y_pred_test)
r2 = r2_score(y_test_test, y_pred_test)

print(f"Średni błąd kwadratowy (MSE): {mse}")
percent_match = r2 * 100
print(f"r2 score: {percent_match:.2f}%")

y_test_test = y_test_test.reset_index(drop=True)
plt.plot([min(y_test_test), max(y_test_test)], [min(y_test_test), max(y_test_test)], 'b', label='y=x')
plt.scatter(y_test_test, y_pred_test)
for i in range(len(y_test_test)):
    plt.plot([y_test_test[i], y_test_test[i]], [y_test_test[i], y_pred_test[i]], 'k--', lw=0.5)
plt.xlabel("Prawdziwe PM2.5")
plt.ylabel("Przewidziane PM2.5")
plt.title("Wykres porównania rzeczywistych i przewidywanych wartości PM2.5")
plt.show()


model_data = pd.read_csv("../../przygotowanie_danych/model_data.csv")
X = model_data[["temperatura", "suma opadów", "wilgotność", "prędkość wiatru", "zachmurzenine", "day_number_in_year"]]
y = model_data['PM2.5']
model_data = model_data.iloc[1788:]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.004,random_state=42)
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


def objective(trial):
    kernel = trial.suggest_categorical('kernel', ['linear', 'poly', 'rbf', 'sigmoid'])
    C = trial.suggest_float('C', 0.1, 200.0)
    epsilon = trial.suggest_float('epsilon', 0.001, 0.5)
    degree = trial.suggest_int('degree', 1, 5)  
    
    coef0 = trial.suggest_float('coef0', -1.0, 1.0)

    model = SVR(kernel=kernel, C=C, epsilon=epsilon,degree=degree,coef0=coef0)

    model.fit(X_train_scaled, y_train)

    y_pred = model.predict(X_test_scaled)

    r2 = r2_score(y_test, y_pred)

    return r2

study = optuna.create_study(direction='maximize') 
stale_count = 0

best_r2 = -float('inf')

r2_values = []

for _ in range(11000):
    study.optimize(objective, n_trials=1)

    if study.best_value > best_r2:
        best_r2 = study.best_value
        stale_count = 0
    else:
        stale_count += 1

    r2_values.append(best_r2)

    if stale_count >= 1000 or best_r2 >= 1.0:
        break

best_params = study.best_params
best_r2 = study.best_value


print("Best Parameters:", best_params)


model = SVR(**best_params)
model.fit(X_train_scaled, y_train)
y_pred = model.predict(X_test_scaled)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Średni błąd kwadratowy (MSE): {mse}")
percent_match = r2 * 100
print(f"Procentowa zgodność: {percent_match:.2f}%")

y_test = y_test.reset_index(drop=True)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], 'r', label='y=x')
plt.scatter(y_test, y_pred)
for i in range(len(y_test)):
    plt.plot([y_test[i], y_test[i]], [y_test[i], y_pred[i]],'k--', lw=0.1)
plt.xlabel("Prawdziwe PM2.5")
plt.ylabel("Przewidziane PM2.5")
plt.title("Wykres porównania rzeczywistych i przewidywanych wartości PM2.5")
plt.show()

results = pd.DataFrame({'Rzeczywiste wartości (y_test)': y_test, 'Przewidywane wartości (y_pred)': y_pred})
results['Różnica'] = abs(results['Rzeczywiste wartości (y_test)'] - results['Przewidywane wartości (y_pred)'])
results.sort_values('Różnica')

model_data_test = pd.read_csv("../../przygotowanie_danych/model_data_test.csv")
model_data_test.index = pd.RangeIndex(start=3487, stop=3517, step=1)
model_data_test
X_test_test = model_data_test[["temperatura", "suma opadów", "wilgotność", "prędkość wiatru", "zachmurzenine", "day_number_in_year"]]
y_test_test = model_data_test['PM2.5']
X_test_test_scaled = scaler.transform(X_test_test)


y_pred_test_2 = model.predict(X_test_test_scaled)
mse = mean_squared_error(y_test_test, y_pred_test_2)
r2 = r2_score(y_test_test, y_pred_test_2)

print(f"Średni błąd kwadratowy (MSE): {mse}")
percent_match = r2 * 100
print(f"r2 score: {percent_match:.2f}%")

y_test_test = y_test_test.reset_index(drop=True)
plt.plot([min(y_test_test), max(y_test_test)], [min(y_test_test), max(y_test_test)],'r', label='y=x')
plt.scatter(y_test_test, y_pred_test_2)
for i in range(len(y_test_test)):
    plt.plot([y_test_test[i], y_test_test[i]], [y_test_test[i], y_pred_test_2[i]], 'k--', lw=0.5)
plt.xlabel("Prawdziwe PM2.5")
plt.ylabel("Przewidziane PM2.5")
plt.title("Wykres porównania rzeczywistych i przewidywanych wartości PM2.5")
plt.show()

plt.figure(figsize=[16,8])
plt.plot(y_test_test,label="rzeczywiste")
plt.plot(y_pred_test,label="rok")
plt.plot(y_pred_test_2,label="tydzein")
plt.legend()
plt.show()

def ocen_jakosc_powietrza(rzeczywiste, przewidywane):
    prog_bardzo_dobry = 13
    prog_dobry = 35
    prog_umiarkowany = 55
    prog_dostateczny = 75
    prog_zly = 110

    kategorie = {
        'bardzo_dobry': (0, prog_bardzo_dobry),
        'dobry': (prog_bardzo_dobry + 0.1, prog_dobry),
        'umiarkowany': (prog_dobry + 0.1, prog_umiarkowany),
        'dostateczny': (prog_umiarkowany + 0.1, prog_dostateczny),
        'zly': (prog_dostateczny + 0.1, prog_zly),
        'bardzo_zly': (prog_zly + 0.1, float('inf'))
    }

    def przyporzadkuj_kategorie(wartosc):
        for kategoria, (min_prog, max_prog) in kategorie.items():
            if min_prog <= wartosc <= max_prog:
                return kategoria

    rzeczywista_kategoria = przyporzadkuj_kategorie(rzeczywiste)
    przewidziana_kategoria = przyporzadkuj_kategorie(przewidywane)

    return rzeczywista_kategoria, przewidziana_kategoria

import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import seaborn as sns

# Przykładowe dane - zastąp tym odpowiednimi danymi
results = pd.DataFrame({
    'Data': pd.date_range(start='2023-09-01', periods=30),
    'Rzeczywiste wartości (y_test)': y_test_test,
    'Przewidywane wartości (y_pred)': y_pred_test
})

# Dodaj kolumny kategorii i porównania
results['Rzeczywista kategoria'], results['Przewidziana kategoria'] = zip(*results.apply(lambda row: ocen_jakosc_powietrza(row['Rzeczywiste wartości (y_test)'], row['Przewidywane wartości (y_pred)']), axis=1))
results['Zgadza się'] = results['Rzeczywista kategoria'] == results['Przewidziana kategoria']
legend_added = False  # Dodaj legendę tylko raz

# Wyodrębnij unikalne daty
unikalne_daty = results['Data'].unique()


procent_poprawnych = results['Zgadza się'].mean() * 100
print(f"Procent dobrze przewidzianych kategorii (zbiór testowy rok): {procent_poprawnych:.2f}%")


plt.figure(figsize=(14, 6))
sns.set_palette("Set2")  # Wybierz zestaw kolorów
for data in unikalne_daty:
    dane_dnia = results[results['Data'] == data]
    color = 'green' if dane_dnia['Zgadza się'].all() else 'red'
    
    
    if not legend_added:
        
        plt.scatter([data]*len(dane_dnia), dane_dnia['Rzeczywiste wartości (y_test)'],label='Rzeczywiste', color=color, marker='o')
        plt.scatter([data]*len(dane_dnia), dane_dnia['Przewidywane wartości (y_pred)'], label='Przewidywane',color=color, marker='x')
        legend_added = True

    plt.scatter([data]*len(dane_dnia), dane_dnia['Rzeczywiste wartości (y_test)'], color=color, marker='o')
    plt.scatter([data]*len(dane_dnia), dane_dnia['Przewidywane wartości (y_pred)'],color=color, marker='x')

    progi_jakosci_powietrza = [13, 35, 55]
    for prog in progi_jakosci_powietrza:
        plt.axhline(y=prog, color='gray', linestyle='--')
plt.legend(loc='upper right')
plt.title('Porównanie przewidywań na poszczególne dni (zbiór testowy rok)')
plt.xlabel('Data')
plt.ylabel('Wartości PM2.5')
plt.xticks(ticks=unikalne_daty, labels=[data.strftime('%Y-%m-%d') for data in unikalne_daty], rotation=45, ha='right')
plt.show()
print("skuteczność:",)



# Przykładowe dane - zastąp tym odpowiednimi danymi
results = pd.DataFrame({
    'Data': pd.date_range(start='2023-09-01', periods=30),
    'Rzeczywiste wartości (y_test)': y_test_test,
    'Przewidywane wartości (y_pred)': y_pred_test_2
})

# Dodaj kolumny kategorii i porównania
results['Rzeczywista kategoria'], results['Przewidziana kategoria'] = zip(*results.apply(lambda row: ocen_jakosc_powietrza(row['Rzeczywiste wartości (y_test)'], row['Przewidywane wartości (y_pred)']), axis=1))
results['Zgadza się'] = results['Rzeczywista kategoria'] == results['Przewidziana kategoria']
legend_added = False  # Dodaj legendę tylko raz

# Wyodrębnij unikalne daty
unikalne_daty = results['Data'].unique()

procent_poprawnych = results['Zgadza się'].mean() * 100
print(f"Procent dobrze przewidzianych kategorii (zbiór testowy tydzień): {procent_poprawnych:.2f}%")

plt.figure(figsize=(14, 6))
sns.set_palette("Set2")  # Wybierz zestaw kolorów
for data in unikalne_daty:
    dane_dnia = results[results['Data'] == data]
    color = 'green' if dane_dnia['Zgadza się'].all() else 'red'
    
    
    if not legend_added:
        
        plt.scatter([data]*len(dane_dnia), dane_dnia['Rzeczywiste wartości (y_test)'],label='Rzeczywiste', color=color, marker='o')
        plt.scatter([data]*len(dane_dnia), dane_dnia['Przewidywane wartości (y_pred)'], label='Przewidywane',color=color, marker='x')
        legend_added = True

    plt.scatter([data]*len(dane_dnia), dane_dnia['Rzeczywiste wartości (y_test)'], color=color, marker='o')
    plt.scatter([data]*len(dane_dnia), dane_dnia['Przewidywane wartości (y_pred)'],color=color, marker='x')

    progi_jakosci_powietrza = [13, 35, 55]
    for prog in progi_jakosci_powietrza:
        plt.axhline(y=prog, color='gray', linestyle='--')
plt.legend(loc='upper right')
plt.title('Porównanie przewidywań na poszczególne dni (zbiór testowy tydzień)')
plt.xlabel('Data')
plt.ylabel('Wartości PM2.5')
plt.xticks(ticks=unikalne_daty, labels=[data.strftime('%Y-%m-%d') for data in unikalne_daty], rotation=45, ha='right')
plt.show()
# Out:
# [I 2023-12-03 11:33:11,002] A new study created in memory with name: no-name-10ea347d-3309-44f9-ab20-3426e6721e15
# [I 2023-12-03 11:33:11,473] Trial 0 finished with value: -11.744981594508202 and parameters: {'kernel': 'poly', 'C': 6.7956746288370296, 'epsilon': 0.12982452845151268, 'degree': 2, 'coef0': -0.4440358125430537}. Best is trial 0 with value: -11.744981594508202.
# [I 2023-12-03 11:33:12,012] Trial 1 finished with value: -34840.776068288484 and parameters: {'kernel': 'sigmoid', 'C': 164.24334435969806, 'epsilon': 0.1141814253562305, 'degree': 5, 'coef0': 0.40834884059508747}. Best is trial 0 with value: -11.744981594508202.
# [I 2023-12-03 11:33:12,444] Trial 2 finished with value: -53234266.8271365 and parameters: {'kernel': 'poly', 'C': 183.41180286260456, 'epsilon': 0.10103818492142005, 'degree': 5, 'coef0': -0.29918453247688714}. Best is trial 0 with value: -11.744981594508202.
# [I 2023-12-03 11:33:13,015] Trial 3 finished with value: -0.39774715464344146 and parameters: {'kernel': 'rbf', 'C': 62.93008778287623, 'epsilon': 0.06763938925999632, 'degree': 4, 'coef0': -0.9858860277497183}. Best is trial 3 with value: -0.39774715464344146.
# [I 2023-12-03 11:33:13,401] Trial 4 finished with value: 0.06743729049291758 and parameters: {'kernel': 'linear', 'C': 153.8268318788334, 'epsilon': 0.25971486549449996, 'degree': 1, 'coef0': 0.1575563414036587}. Best is trial 4 with value: 0.06743729049291758.
# [I 2023-12-03 11:33:13,814] Trial 5 finished with value: -803.7662570647017 and parameters: {'kernel': 'poly', 'C': 6.237156233997477, 'epsilon': 0.3966697693799808, 'degree': 3, 'coef0': -0.6592330242672115}. Best is trial 4 with value: 0.06743729049291758.
# [I 2023-12-03 11:33:14,366] Trial 6 finished with value: -387921.1441580583 and parameters: {'kernel': 'sigmoid', 'C': 153.20018150497978, 'epsilon': 0.12062434174727729, 'degree': 4, 'coef0': -0.3284135068850993}. Best is trial 4 with value: 0.06743729049291758.
# [I 2023-12-03 11:33:14,665] Trial 7 finished with value: 0.07003183095605592 and parameters: {'kernel': 'linear', 'C': 62.22860515240598, 'epsilon': 0.34988382596231576, 'degree': 1, 'coef0': -0.6990376214100373}. Best is trial 7 with value: 0.07003183095605592.
# [I 2023-12-03 11:33:15,210] Trial 8 finished with value: -21532.47971494031 and parameters: {'kernel': 'sigmoid', 'C': 113.42928485070406, 'epsilon': 0.06710681540262625, 'degree': 5, 'coef0': 0.3386171905290509}. Best is trial 7 with value: 0.07003183095605592.
# [I 2023-12-03 11:34:07,524] Trial 9 finished with value: -0.3076908011503696 and parameters: {'kernel': 'poly', 'C': 40.945176582124816, 'epsilon': 0.21521720731973526, 'degree': 5, 'coef0': 0.4931767179393165}. Best is trial 7 with value: 0.07003183095605592.
. Best is trial 22 with value: 0.07140027404976534.
# [I 2023-12-03 11:34:28,711] Trial 53 finished with value: 0.07114661477343687 and parameters: {'kernel': 'linear', 'C': 148.16083864151435, 'epsilon': 0.21650560409756997, 'degree': 1, 'coef0': -0.8548176559846693}. Best is trial 22 with value: 0.07140027404976534.
# [I 2023-12-03 11:34:29,086] Trial 54 finished with value: 0.0683783344444786 and parameters: {'kernel': 'linear', 'C': 139.7218906164533, 'epsilon': 0.2516077599921083, 'degree': 1, 'coef0': -0.82701746698593}. Best is trial 22 with value: 0.07140027404976534.
# [I 2023-12-03 11:34:29,464] Trial 55 finished with value: 0.07120021051217762 and parameters: {'kernel': 'linear', 'C': 149.5016593524408, 'epsilon': 0.2139348150506894, 'degree': 1, 'coef0': -0.7377434296629252}. Best is trial 22 with value: 0.07140027404976534.
# [I 2023-12-03 11:34:29,831] Trial 56 finished with value: 0.07052487478449865 and parameters: {'kernel': 'linear', 'C': 130.90784672686178, 'epsilon': 0.15826350711211581, 'degree': 1, 'coef0': -0.7358079834403104}. Best is trial 22 with value: 0.07140027404976534.
# [I 2023-12-03 11:34:30,413] Trial 57 finished with value: -786452.3072654384 and parameters: {'kernel': 'sigmoid', 'C': 146.13917942742668, 'epsilon': 0.1804537028250413, 'degree': 1, 'coef0': -0.6107023490120133}. Best is trial 22 with value: 0.07140027404976534.
# [I 2023-12-03 11:34:30,819] Trial 58 finished with value: 0.07095609124228319 and parameters: {'kernel': 'linear', 'C': 139.43261377887887, 'epsilon': 0.20290708662192722, 'degree': 4, 'coef0': -0.47017905494407575}. Best is trial 22 with value: 0.07140027404976534.
# [I 2023-12-03 11:34:31,244] Trial 59 finished with value: 0.06657624375061955 and parameters: {'kernel': 'poly', 'C': 118.63844314484625, 'epsilon': 0.2640566294408204, 'degree': 1, 'coef0': -0.8237592771608809}. Best is trial 22 with value: 0.07140027404976534.
# [I 2023-12-03 11:34:31,630] Trial 60 finished with value: 0.07035896990368407 and parameters: {'kernel': 'linear', 'C': 127.68700933316975, 'epsilon': 0.24000400390939253, 'degree': 1, 'coef0': -0.7154596138380636}. Best is trial 22 with value: 0.07140027404976534.
# [I 2023-12-03 11:34:32,025] Trial 61 finished with value: 0.0710245508669588 and parameters: {'kernel': 'linear', 'C': 162.6235944174145, 'epsilon': 0.21993766199762474, 'degree': 1, 'coef0': -0.9516492585245362}. Best is trial 22 with value: 0.07140027404976534.
# [I 2023-12-03 11:34:32,435] Trial 62 finished with value: 0.0705771038883567 and parameters: {'kernel': 'linear', 'C': 161.56230966103794, 'epsilon': 0.2032329254628568, 'degree': 1, 'coef0': -0.9517931514798396}. Best is trial 22 with value: 0.07140027404976534.
# [I 2023-12-03 11:34:32,844] Trial 63 finished with value: 0.06998912237750798 and parameters: {'kernel': 'linear', 'C': 171.53093397734983, 'epsilon': 0.18328173415435992, 'degree': 1, 'coef0': -0.8491679818192579}. Best is trial 22 with value: 0.07140027404976534.
# [I 2023-12-03 11:34:33,317] Trial 64 finished with value: 0.0712426333597137 and parameters: {'kernel': 'linear', 'C': 145.86906539346407, 'epsilon': 0.21409500807315207, 'degree': 5, 'coef0': -0.7541285429272856}. Best is trial 22 with value: 0.07140027404976534.
# [I 2023-12-03 11:34:33,766] Trial 65 finished with value: 0.07128725407466363 and parameters: {'kernel': 'linear', 'C': 174.60921611766904, 'epsilon': 0.2140180434268028, 'degree': 1, 'coef0': -0.7580548874014991}. Best is trial 22 with value: 0.07140027404976534.
# [I 2023-12-03 11:34:34,186] Trial 66 finished with value: 0.07136047581684768 and parameters: {'kernel': 'linear', 'C': 173.1766214294489, 'epsilon': 0.21260657144901793, 'degree': 5, 'coef0': -0.7593160273465281}. Best is trial 22 with value: 0.07140027404976534.
# [I 2023-12-03 11:34:34,649] Trial 67 finished with value: 0.07036125107552826 and parameters: {'kernel': 'linear', 'C': 175.4405957655447, 'epsilon': 0.24009464185517732, 'degree': 5, 'coef0': -0.7658338480954604}. Best is trial 22 with value: 0.07140027404976534.
# [I 2023-12-03 11:34
. Best is trial 74 with value: 0.07142175778413629.
# [I 2023-12-03 11:35:04,109] Trial 131 finished with value: 0.07112775226679269 and parameters: {'kernel': 'linear', 'C': 148.68028568168393, 'epsilon': 0.2167260000562457, 'degree': 5, 'coef0': -0.742138292458706}. Best is trial 74 with value: 0.07142175778413629.
# [I 2023-12-03 11:35:04,531] Trial 132 finished with value: 0.0708613653030028 and parameters: {'kernel': 'linear', 'C': 151.4706600401976, 'epsilon': 0.20960992121242097, 'degree': 5, 'coef0': -0.7767315967049926}. Best is trial 74 with value: 0.07142175778413629.
# [I 2023-12-03 11:35:04,943] Trial 133 finished with value: 0.07129277690218383 and parameters: {'kernel': 'linear', 'C': 151.2097532544798, 'epsilon': 0.19879087395123904, 'degree': 5, 'coef0': -0.8661117259119059}. Best is trial 74 with value: 0.07142175778413629.
# [I 2023-12-03 11:35:05,358] Trial 134 finished with value: 0.06974959437006123 and parameters: {'kernel': 'linear', 'C': 157.12625654053443, 'epsilon': 0.17448519014330838, 'degree': 5, 'coef0': -0.8342724142651448}. Best is trial 74 with value: 0.07142175778413629.
# [I 2023-12-03 11:35:05,778] Trial 135 finished with value: 0.07113786113478815 and parameters: {'kernel': 'linear', 'C': 136.1436632924117, 'epsilon': 0.19811721462093906, 'degree': 5, 'coef0': -0.9003113956560188}. Best is trial 74 with value: 0.07142175778413629.
# [I 2023-12-03 11:35:06,184] Trial 136 finished with value: 0.070485866854199 and parameters: {'kernel': 'linear', 'C': 165.48246756294174, 'epsilon': 0.23285384161902617, 'degree': 5, 'coef0': -0.8508754897688685}. Best is trial 74 with value: 0.07142175778413629.
# [I 2023-12-03 11:35:06,588] Trial 137 finished with value: 0.06970593650663393 and parameters: {'kernel': 'linear', 'C': 156.38944810669108, 'epsilon': 0.18446966042621216, 'degree': 1, 'coef0': -0.6282659655392657}. Best is trial 74 with value: 0.07142175778413629.
# [I 2023-12-03 11:35:07,005] Trial 138 finished with value: 0.0713790800455828 and parameters: {'kernel': 'linear', 'C': 173.39130993154436, 'epsilon': 0.19979304540201517, 'degree': 5, 'coef0': -0.9551832202522693}. Best is trial 74 with value: 0.07142175778413629.
# [I 2023-12-03 11:35:07,415] Trial 139 finished with value: 0.06707734864530812 and parameters: {'kernel': 'linear', 'C': 175.627585888631, 'epsilon': 0.14683604244006576, 'degree': 5, 'coef0': -0.9354614274780977}. Best is trial 74 with value: 0.07142175778413629.
# [I 2023-12-03 11:35:07,815] Trial 140 finished with value: 0.0712489840942917 and parameters: {'kernel': 'linear', 'C': 181.4536646127315, 'epsilon': 0.19833587178811904, 'degree': 5, 'coef0': -0.9836325745485632}. Best is trial 74 with value: 0.07142175778413629.
# [I 2023-12-03 11:35:08,230] Trial 141 finished with value: 0.07135692926331405 and parameters: {'kernel': 'linear', 'C': 182.3402331756466, 'epsilon': 0.19953108491010335, 'degree': 5, 'coef0': -0.965294724249635}. Best is trial 74 with value: 0.07142175778413629.
# [I 2023-12-03 11:35:08,649] Trial 142 finished with value: 0.06983491039348655 and parameters: {'kernel': 'linear', 'C': 182.12639020415975, 'epsilon': 0.19356448363425344, 'degree': 5, 'coef0': -0.9917939889374044}. Best is trial 74 with value: 0.07142175778413629.
# [I 2023-12-03 11:35:09,046] Trial 143 finished with value: 0.07139901660734682 and parameters: {'kernel': 'linear', 'C': 183.0796678858903, 'epsilon': 0.20133985311245592, 'degree': 5, 'coef0': -0.8859970482850636}. Best is trial 74 with value: 0.07142175778413629.
# [I 2023-12-03 11:35:09,477] Trial 144 finished with value: 0.07140230432329642 and parameters: {'kernel': 'linear', 'C': 184.98350577881686, 'epsilon': 0.20130540544416542, 'degree': 5, 'coef0': -0.895836784923715}. Best is trial 74 with value: 0.07142175778413629.
# [I 2023-12-03 11:35:09,916] Trial 145 finished with value: 0.0696809954195774 and parameters: {'kernel': 'linear', 'C': 193.03531447729287, 'epsilon': 0.17305182633136285, 'degree': 5, 'coef0': -0.8897814719852079}. Best is trial 74 with value: 0.07142175778413629.
# [I 2023-12-03 11:35:10,332] Trial 146 finished with value: 0.06963424697635234 and parameters: {'kernel': 'linear', 'C': 187.79449337792153, 'epsilon': 0.18493348669252102, 'degree': 5, 'coef0': -0.8802683651490959}. Best is trial 74 with value: 0.07142175778413629.
# [I 2023-12-03 11:35
# [I 2023-12-03 11:51:09,658] Trial 1870 finished with value: -0.22923389118165427 and parameters: {'kernel': 'poly', 'C': 27.52638412313395, 'epsilon': 0.4524649555931266, 'degree': 3, 'coef0': 0.0770109274707816}. Best is trial 1702 with value: 0.23153698227483344.
# [I 2023-12-03 11:51:10,191] Trial 1871 finished with value: -0.21853998942191222 and parameters: {'kernel': 'rbf', 'C': 7.2121160408511615, 'epsilon': 0.1175747769040503, 'degree': 3, 'coef0': -0.673049639523093}. Best is trial 1702 with value: 0.23153698227483344.
# [I 2023-12-03 11:51:10,727] Trial 1872 finished with value: -0.2814103945140669 and parameters: {'kernel': 'rbf', 'C': 17.131903968513807, 'epsilon': 0.019136895221531856, 'degree': 3, 'coef0': -0.7799701603487313}. Best is trial 1702 with value: 0.23153698227483344.
# [I 2023-12-03 11:51:11,242] Trial 1873 finished with value: -0.07919907469443577 and parameters: {'kernel': 'rbf', 'C': 3.600096519064834, 'epsilon': 0.07710841928847786, 'degree': 3, 'coef0': -0.5773846930256503}. Best is trial 1702 with value: 0.23153698227483344.
# [I 2023-12-03 11:51:11,745] Trial 1874 finished with value: 0.22716200427190447 and parameters: {'kernel': 'rbf', 'C': 0.11482758195526482, 'epsilon': 0.169610870468374, 'degree': 3, 'coef0': 0.7708788037464005}. Best is trial 1702 with value: 0.23153698227483344.
# [I 2023-12-03 11:51:12,288] Trial 1875 finished with value: -0.37914498966680465 and parameters: {'kernel': 'rbf', 'C': 29.893092966882065, 'epsilon': 0.048924368521624496, 'degree': 3, 'coef0': -0.036993893310803314}. Best is trial 1702 with value: 0.23153698227483344.
# [I 2023-12-03 11:51:12,773] Trial 1876 finished with value: 0.22914569678330465 and parameters: {'kernel': 'rbf', 'C': 0.13186759966182876, 'epsilon': 0.1480148309850715, 'degree': 3, 'coef0': -0.19900614372941897}. Best is trial 1702 with value: 0.23153698227483344.
# [I 2023-12-03 11:51:13,297] Trial 1877 finished with value: -0.24587854278767396 and parameters: {'kernel': 'rbf', 'C': 9.822843997676959, 'epsilon': 0.1699591419970109, 'degree': 3, 'coef0': -0.2094722936846568}. Best is trial 1702 with value: 0.23153698227483344.
# [I 2023-12-03 11:51:13,802] Trial 1878 finished with value: -0.19544054527918298 and parameters: {'kernel': 'rbf', 'C': 6.493455582466424, 'epsilon': 0.14625506055845072, 'degree': 3, 'coef0': -0.24691174484158263}. Best is trial 1702 with value: 0.23153698227483344.
# [W 2023-12-03 11:51:13,857] Trial 1879 failed with parameters: {'kernel': 'rbf', 'C': 0.11869420094333107, 'epsilon': 0.15651520114710174} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "c:\Users\48516\Desktop\inzynierka\.venv\Lib\site-packages\optuna\study\_optimize.py", line 200, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\48516\AppData\Local\Temp\ipykernel_13340\1097915413.py", line 26, in objective
#     degree = trial.suggest_int('degree', 1, 5)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\48516\Desktop\inzynierka\.venv\Lib\site-packages\optuna\trial\_trial.py", line 321, in suggest_int
#     suggested_value = int(self._suggest(name, distribution))
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\48516\Desktop\inzynierka\.venv\Lib\site-packages\optuna\trial\_trial.py", line 630, in _suggest
#     param_value = self.study.sampler.sample_independent(
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\48516\Desktop\inzynierka\.venv\Lib\site-packages\optuna\samplers\_tpe\sampler.py", line 423, in sample_independent
#     return self._sample(study, trial, {param_name: param_distribution})[param_name]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\48516\Desktop\inzynierka\.venv\Lib\site-packages\optuna\samplers\_tpe\sampler.py", line 474, in _sample
#     mpe_above = _ParzenEstimator(above, search_space, self._parzen_estimator_parameters)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\48516\Desktop\inzynierka\.venv\Lib\site-packages\optuna\samplers\_tpe\parzen_estimator.py", line 67, in __init__
#     else self._call_weights_func(parameters.weights, len(transformed_observations))
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\48516\Desktop\inzynierka\.venv\Lib\site-packages\optuna\samplers\_tpe\parzen_estimator.py", line 96, in _call_weights_func
#     w = np.array(weights_func(n))[:n]
#                  ^^^^^^^^^^^^^^^
#   File "c:\Users\48516\Desktop\inzynierka\.venv\Lib\site-packages\optuna\samplers\_tpe\sampler.py", line 55, in default_weights
#     ramp = np.linspace(1.0 / x, 1.0, num=x - 25)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\48516\Desktop\inzynierka\.venv\Lib\site-packages\numpy\core\function_base.py", line 182, in linspace
#     return y.astype(dtype, copy=False)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# [W 2023-12-03 11:51:13,861] Trial 1879 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\48516\Desktop\inzynierka\aktualne\modele\odrzucone\SVR_3years.ipynb Cell 1 line 4
#      <a href='vscode-notebook-cell:/c%3A/Users/48516/Desktop/inzynierka/aktualne/modele/odrzucone/SVR_3years.ipynb#W0sZmlsZQ%3D%3D?line=44'>45</a> r2_values = []
#      <a href='vscode-notebook-cell:/c%3A/Users/48516/Desktop/inzynierka/aktualne/modele/odrzucone/SVR_3years.ipynb#W0sZmlsZQ%3D%3D?line=46'>47</a> for _ in range(11000):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/48516/Desktop/inzynierka/aktualne/modele/odrzucone/SVR_3years.ipynb#W0sZmlsZQ%3D%3D?line=47'>48</a>     study.optimize(objective, n_trials=1)
#      <a href='vscode-notebook-cell:/c%3A/Users/48516/Desktop/inzynierka/aktualne/modele/odrzucone/SVR_3years.ipynb#W0sZmlsZQ%3D%3D?line=49'>50</a>     if study.best_value > best_r2:
#      <a href='vscode-notebook-cell:/c%3A/Users/48516/Desktop/inzynierka/aktualne/modele/odrzucone/SVR_3years.ipynb#W0sZmlsZQ%3D%3D?line=50'>51</a>         best_r2 = study.best_value
#
# File c:\Users\48516\Desktop\inzynierka\.venv\Lib\site-packages\optuna\study\study.py:451, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     348 def optimize(
#     349     self,
#     350     func: ObjectiveFuncType,
#    (...)
#     357     show_progress_bar: bool = False,
#     358 ) -> None:
#     359     """Optimize an objective function.
#     360
#     361     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     449             If nested invocation of this method occurs.
#     450     """
# --> 451     _optimize(
#     452         study=self,
#     453         func=func,
#     454         n_trials=n_trials,
#     455         timeout=timeout,
#     456         n_jobs=n_jobs,
#     457         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     458         callbacks=callbacks,
#     459         gc_after_trial=gc_after_trial,
#     460         show_progress_bar=show_progress_bar,
#     461     )
#
# File c:\Users\48516\Desktop\inzynierka\.venv\Lib\site-packages\optuna\study\_optimize.py:66, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64 try:
#      65     if n_jobs == 1:
# ---> 66         _optimize_sequential(
#      67             study,
#      68             func,
#      69             n_trials,
#      70             timeout,
#      71             catch,
#      72             callbacks,
#      73             gc_after_trial,
#      74             reseed_sampler_rng=False,
#      75             time_start=None,
#      76             progress_bar=progress_bar,
#      77         )
#      78     else:
#      79         if n_jobs == -1:
#
# File c:\Users\48516\Desktop\inzynierka\.venv\Lib\site-packages\optuna\study\_optimize.py:163, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     160         break
#     162 try:
# --> 163     frozen_trial = _run_trial(study, func, catch)
#     164 finally:
#     165     # The following line mitigates memory problems that can be occurred in some
#     166     # environments (e.g., services that use computing containers such as GitHub Actions).
#     167     # Please refer to the following PR for further details:
#     168     # https://github.com/optuna/optuna/pull/325.
#     169     if gc_after_trial:
#
# File c:\Users\48516\Desktop\inzynierka\.venv\Lib\site-packages\optuna\study\_optimize.py:251, in _run_trial(study, func, catch)
#     244         assert False, "Should not reach."
#     246 if (
#     247     frozen_trial.state == TrialState.FAIL
#     248     and func_err is not None
#     249     and not isinstance(func_err, catch)
#     250 ):
# --> 251     raise func_err
#     252 return frozen_trial
#
# File c:\Users\48516\Desktop\inzynierka\.venv\Lib\site-packages\optuna\study\_optimize.py:200, in _run_trial(study, func, catch)
#     198 with get_heartbeat_thread(trial._trial_id, study._storage):
#     199     try:
# --> 200         value_or_values = func(trial)
#     201     except exceptions.TrialPruned as e:
#     202         # TODO(mamu): Handle multi-objective cases.
#     203         state = TrialState.PRUNED
#
# c:\Users\48516\Desktop\inzynierka\aktualne\modele\odrzucone\SVR_3years.ipynb Cell 1 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/48516/Desktop/inzynierka/aktualne/modele/odrzucone/SVR_3years.ipynb#W0sZmlsZQ%3D%3D?line=23'>24</a> C = trial.suggest_float('C', 0.1, 200.0)
#      <a href='vscode-notebook-cell:/c%3A/Users/48516/Desktop/inzynierka/aktualne/modele/odrzucone/SVR_3years.ipynb#W0sZmlsZQ%3D%3D?line=24'>25</a> epsilon = trial.suggest_float('epsilon', 0.001, 0.5)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/48516/Desktop/inzynierka/aktualne/modele/odrzucone/SVR_3years.ipynb#W0sZmlsZQ%3D%3D?line=25'>26</a> degree = trial.suggest_int('degree', 1, 5)
#      <a href='vscode-notebook-cell:/c%3A/Users/48516/Desktop/inzynierka/aktualne/modele/odrzucone/SVR_3years.ipynb#W0sZmlsZQ%3D%3D?line=27'>28</a> coef0 = trial.suggest_float('coef0', -1.0, 1.0)
#      <a href='vscode-notebook-cell:/c%3A/Users/48516/Desktop/inzynierka/aktualne/modele/odrzucone/SVR_3years.ipynb#W0sZmlsZQ%3D%3D?line=29'>30</a> model = SVR(kernel=kernel, C=C, epsilon=epsilon,degree=degree,coef0=coef0)
#
# File c:\Users\48516\Desktop\inzynierka\.venv\Lib\site-packages\optuna\trial\_trial.py:321, in Trial.suggest_int(self, name, low, high, step, log)
#     239 """Suggest a value for the integer parameter.
#     240
#     241 The value is sampled from the integers in :math:`[\\mathsf{low}, \\mathsf{high}]`.
#    (...)
#     317     :ref:`configurations` tutorial describes more details and flexible usages.
#     318 """
#     320 distribution = IntDistribution(low=low, high=high, log=log, step=step)
# --> 321 suggested_value = int(self._suggest(name, distribution))
#     322 self._check_distribution(name, distribution)
#     323 return suggested_value
#
# File c:\Users\48516\Desktop\inzynierka\.venv\Lib\site-packages\optuna\trial\_trial.py:630, in Trial._suggest(self, name, distribution)
#     628 else:
#     629     study = pruners._filter_study(self.study, trial)
# --> 630     param_value = self.study.sampler.sample_independent(
#     631         study, trial, name, distribution
#     632     )
#     634 # `param_value` is validated here (invalid value like `np.nan` raises ValueError).
#     635 param_value_in_internal_repr = distribution.to_internal_repr(param_value)
#
# File c:\Users\48516\Desktop\inzynierka\.venv\Lib\site-packages\optuna\samplers\_tpe\sampler.py:423, in TPESampler.sample_independent(self, study, trial, param_name, param_distribution)
#     413     if any(param_name in trial.params for trial in trials):
#     414         _logger.warning(
#     415             f"The parameter '{param_name}' in trial#{trial.number} is sampled "
#     416             "independently instead of being sampled by multivariate TPE sampler. "
#    (...)
#     420             "if this independent sampling is intended behavior."
#     421         )
# --> 423 return self._sample(study, trial, {param_name: param_distribution})[param_name]
#
# File c:\Users\48516\Desktop\inzynierka\.venv\Lib\site-packages\optuna\samplers\_tpe\sampler.py:474, in TPESampler._sample(self, study, trial, search_space)
#     472 else:
#     473     mpe_below = _ParzenEstimator(below, search_space, self._parzen_estimator_parameters)
# --> 474 mpe_above = _ParzenEstimator(above, search_space, self._parzen_estimator_parameters)
#     475 samples_below = mpe_below.sample(self._rng.rng, self._n_ei_candidates)
#     476 log_likelihoods_below = mpe_below.log_pdf(samples_below)
#
# File c:\Users\48516\Desktop\inzynierka\.venv\Lib\site-packages\optuna\samplers\_tpe\parzen_estimator.py:67, in _ParzenEstimator.__init__(self, observations, search_space, parameters, predetermined_weights)
#      59 transformed_observations = self._transform(observations)
#      61 assert predetermined_weights is None or len(transformed_observations) == len(
#      62     predetermined_weights
#      63 )
#      64 weights = (
#      65     predetermined_weights
#      66     if predetermined_weights is not None
# ---> 67     else self._call_weights_func(parameters.weights, len(transformed_observations))
#      68 )
#      70 if len(transformed_observations) == 0:
#      71     weights = np.array([1.0])
#
# File c:\Users\48516\Desktop\inzynierka\.venv\Lib\site-packages\optuna\samplers\_tpe\parzen_estimator.py:96, in _ParzenEstimator._call_weights_func(weights_func, n)
#      94 @staticmethod
#      95 def _call_weights_func(weights_func: Callable[[int], np.ndarray], n: int) -> np.ndarray:
# ---> 96     w = np.array(weights_func(n))[:n]
#      97     if np.any(w < 0):
#      98         raise ValueError(
#      99             f"The `weights` function is not allowed to return negative values {w}. "
#     100             + f"The argument of the `weights` function is {n}."
#     101         )
#
# File c:\Users\48516\Desktop\inzynierka\.venv\Lib\site-packages\optuna\samplers\_tpe\sampler.py:55, in default_weights(x)
#      53     return np.ones(x)
#      54 else:
# ---> 55     ramp = np.linspace(1.0 / x, 1.0, num=x - 25)
#      56     flat = np.ones(25)
#      57     return np.concatenate([ramp, flat], axis=0)
#
# File c:\Users\48516\Desktop\inzynierka\.venv\Lib\site-packages\numpy\core\function_base.py:182, in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     180     return y.astype(dtype, copy=False), step
#     181 else:
# --> 182     return y.astype(dtype, copy=False)
#
# KeyboardInterrupt:
