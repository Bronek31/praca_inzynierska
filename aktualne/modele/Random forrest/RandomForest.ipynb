# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.preprocessing import StandardScaler,MinMaxScaler
import optuna
from sklearn.svm import SVR
from sklearn.metrics import r2_score, mean_squared_error
import matplotlib.patches as mpatches
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor



model_data = pd.read_csv("../../przygotowanie_danych/model_data.csv")
X = model_data[["temperatura", "suma opadów", "wilgotność", "prędkość wiatru", "zachmurzenine", "day_number_in_year"]]
y = model_data['PM2.5']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1,shuffle=False)
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 1, 1000)
    max_depth = trial.suggest_int('max_depth', 1, 2500)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 100)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 100)
    max_features = trial.suggest_float('max_features', 0.1, 1.0)
    min_weight_fraction_leaf = trial.suggest_float('min_weight_fraction_leaf', 0.0, 0.5)

    # # Additional parameters
    # criterion = trial.suggest_categorical('criterion',  {'friedman_mse', 'squared_error', 'poisson', 'absolute_error'})
    # max_leaf_nodes = trial.suggest_int('max_leaf_nodes', 10, 100)
    # min_impurity_decrease = trial.suggest_float('min_impurity_decrease', 0.0, 0.1)
    # verbose = trial.suggest_categorical('verbose', [0, 1, 2])
    # ccp_alpha = trial.suggest_float('ccp_alpha', 0.0, 0.5)
  

    model = RandomForestRegressor(
        n_estimators=n_estimators,
        # criterion=criterion,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        min_weight_fraction_leaf=min_weight_fraction_leaf,
        max_features=max_features,
        # max_leaf_nodes=max_leaf_nodes,
        # min_impurity_decrease=min_impurity_decrease,
        bootstrap=False,
        # n_jobs=-1,
        random_state=42,
        # verbose=verbose,
        # ccp_alpha=ccp_alpha,
        max_samples=None

    )

    model.fit(X_train_scaled, y_train)

    y_pred = model.predict(X_test_scaled)

    r2 = r2_score(y_test, y_pred)

    return r2

study = optuna.create_study(direction='maximize') 
stale_count = 0

best_r2 = -float('inf')

r2_values = []

for _ in range(11000):
    study.optimize(objective, n_trials=1)

    if study.best_value > best_r2:
        best_r2 = study.best_value
        stale_count = 0
    else:
        stale_count += 1

    r2_values.append(best_r2)

    if stale_count >= 100 or best_r2 >= 1.0:
        break

best_params = study.best_params
best_r2 = study.best_value

print("Best Parameters:", best_params)



model = RandomForestRegressor(**best_params,random_state=42)
model.fit(X_train_scaled, y_train)
y_pred = model.predict(X_test_scaled)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Średni błąd kwadratowy (MSE): {mse}")
percent_match = r2 * 100
print(f"Procentowa zgodność: {percent_match:.2f}%")

y_test = y_test.reset_index(drop=True)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], 'r', label='y=x')
plt.scatter(y_test, y_pred)
for i in range(len(y_test)):
    plt.plot([y_test[i], y_test[i]], [y_test[i], y_pred[i]],'k--', lw=0.1)
plt.xlabel("Prawdziwe PM2.5")
plt.ylabel("Przewidziane PM2.5")
plt.title("Wykres porównania rzeczywistych i przewidywanych wartości PM2.5")
plt.show()

results = pd.DataFrame({'Rzeczywiste wartości (y_test)': y_test, 'Przewidywane wartości (y_pred)': y_pred})
results['Różnica'] = abs(results['Rzeczywiste wartości (y_test)'] - results['Przewidywane wartości (y_pred)'])
results.sort_values('Różnica')

model_data_test = pd.read_csv("../../przygotowanie_danych/model_data_test.csv")
model_data_test.index = pd.RangeIndex(start=3487, stop=3517, step=1)
model_data_test
X_test_test = model_data_test[["temperatura", "suma opadów", "wilgotność", "prędkość wiatru", "zachmurzenine", "day_number_in_year"]]
y_test_test = model_data_test['PM2.5']
X_test_test_scaled = scaler.transform(X_test_test)

y_pred_test = model.predict(X_test_test_scaled)
mse = mean_squared_error(y_test_test, y_pred_test)
r2 = r2_score(y_test_test, y_pred_test)

print(f"Średni błąd kwadratowy (MSE): {mse}")
percent_match = r2 * 100
print(f"r2 score: {percent_match:.2f}%")

y_test_test = y_test_test.reset_index(drop=True)
plt.plot([min(y_test_test), max(y_test_test)], [min(y_test_test), max(y_test_test)], 'b', label='y=x')
plt.scatter(y_test_test, y_pred_test)
for i in range(len(y_test_test)):
    plt.plot([y_test_test[i], y_test_test[i]], [y_test_test[i], y_pred_test[i]], 'k--', lw=0.5)
plt.xlabel("Prawdziwe PM2.5")
plt.ylabel("Przewidziane PM2.5")
plt.title("Wykres porównania rzeczywistych i przewidywanych wartości PM2.5")
plt.show()


model_data = pd.read_csv("../../przygotowanie_danych/model_data.csv")
X = model_data[["temperatura", "suma opadów", "wilgotność", "prędkość wiatru", "zachmurzenine", "day_number_in_year"]]
y = model_data['PM2.5']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.002,random_state=42)
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 1, 1000)
    max_depth = trial.suggest_int('max_depth', 1, 2500)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 100)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 100)
    max_features = trial.suggest_float('max_features', 0.1, 1.0)
    min_weight_fraction_leaf = trial.suggest_float('min_weight_fraction_leaf', 0.0, 0.5)

    # # Additional parameters
    # criterion = trial.suggest_categorical('criterion',  {'friedman_mse', 'squared_error', 'poisson', 'absolute_error'})
    # max_leaf_nodes = trial.suggest_int('max_leaf_nodes', 10, 100)
    # min_impurity_decrease = trial.suggest_float('min_impurity_decrease', 0.0, 0.1)
    # verbose = trial.suggest_categorical('verbose', [0, 1, 2])
    # ccp_alpha = trial.suggest_float('ccp_alpha', 0.0, 0.5)
  

    model = RandomForestRegressor(
        n_estimators=n_estimators,
        # criterion=criterion,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        min_weight_fraction_leaf=min_weight_fraction_leaf,
        max_features=max_features,
        # max_leaf_nodes=max_leaf_nodes,
        # min_impurity_decrease=min_impurity_decrease,
        bootstrap=False,
        # n_jobs=-1,
        random_state=42,
        # verbose=verbose,
        # ccp_alpha=ccp_alpha,
        max_samples=None

    )

    model.fit(X_train_scaled, y_train)

    y_pred = model.predict(X_test_scaled)

    r2 = r2_score(y_test, y_pred)

    return r2

study = optuna.create_study(direction='maximize') 
stale_count = 0

best_r2 = -float('inf')

r2_values = []

for _ in range(11000):
    study.optimize(objective, n_trials=1)

    if study.best_value > best_r2:
        best_r2 = study.best_value
        stale_count = 0
    else:
        stale_count += 1

    r2_values.append(best_r2)

    if stale_count >= 100 or best_r2 >= 1.0:
        break

best_params = study.best_params
best_r2 = study.best_value

print("Best Parameters:", best_params)



model = RandomForestRegressor(**best_params,random_state=42)
model.fit(X_train_scaled, y_train)
y_pred = model.predict(X_test_scaled)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Średni błąd kwadratowy (MSE): {mse}")
percent_match = r2 * 100
print(f"Procentowa zgodność: {percent_match:.2f}%")

y_test = y_test.reset_index(drop=True)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], 'r', label='y=x')
plt.scatter(y_test, y_pred)
for i in range(len(y_test)):
    plt.plot([y_test[i], y_test[i]], [y_test[i], y_pred[i]],'k--', lw=0.1)
plt.xlabel("Prawdziwe PM2.5")
plt.ylabel("Przewidziane PM2.5")
plt.title("Wykres porównania rzeczywistych i przewidywanych wartości PM2.5")
plt.show()

results = pd.DataFrame({'Rzeczywiste wartości (y_test)': y_test, 'Przewidywane wartości (y_pred)': y_pred})
results['Różnica'] = abs(results['Rzeczywiste wartości (y_test)'] - results['Przewidywane wartości (y_pred)'])
results.sort_values('Różnica')

model_data_test = pd.read_csv("../../przygotowanie_danych/model_data_test.csv")
model_data_test.index = pd.RangeIndex(start=3487, stop=3517, step=1)
model_data_test
X_test_test = model_data_test[["temperatura", "suma opadów", "wilgotność", "prędkość wiatru", "zachmurzenine", "day_number_in_year"]]
y_test_test = model_data_test['PM2.5']
X_test_test_scaled = scaler.transform(X_test_test)


y_pred_test_2 = model.predict(X_test_test_scaled)
mse = mean_squared_error(y_test_test, y_pred_test_2)
r2 = r2_score(y_test_test, y_pred_test_2)

print(f"Średni błąd kwadratowy (MSE): {mse}")
percent_match = r2 * 100
print(f"r2 score: {percent_match:.2f}%")

y_test_test = y_test_test.reset_index(drop=True)
plt.plot([min(y_test_test), max(y_test_test)], [min(y_test_test), max(y_test_test)],'r', label='y=x')
plt.scatter(y_test_test, y_pred_test_2)
for i in range(len(y_test_test)):
    plt.plot([y_test_test[i], y_test_test[i]], [y_test_test[i], y_pred_test_2[i]], 'k--', lw=0.5)
plt.xlabel("Prawdziwe PM2.5")
plt.ylabel("Przewidziane PM2.5")
plt.title("Wykres porównania rzeczywistych i przewidywanych wartości PM2.5")
plt.show()


plt.figure(figsize=[16,8])
plt.plot(y_test_test)
plt.plot(y_pred_test)
plt.plot(y_pred_test_2)
plt.show()
def ocen_jakosc_powietrza(rzeczywiste, przewidywane):
    prog_bardzo_dobry = 12
    prog_dobry = 35
    prog_umiarkowany = 55
    prog_dostateczny = 75
    prog_zly = 110

    kategorie = {
        'bardzo_dobry': (0, prog_bardzo_dobry),
        'dobry': (prog_bardzo_dobry + 0.1, prog_dobry),
        'umiarkowany': (prog_dobry + 0.1, prog_umiarkowany),
        'dostateczny': (prog_umiarkowany + 0.1, prog_dostateczny),
        'zly': (prog_dostateczny + 0.1, prog_zly),
        'bardzo_zly': (prog_zly + 0.1, float('inf'))
    }

    def przyporzadkuj_kategorie(wartosc):
        for kategoria, (min_prog, max_prog) in kategorie.items():
            if min_prog <= wartosc <= max_prog:
                return kategoria

    rzeczywista_kategoria = przyporzadkuj_kategorie(rzeczywiste)
    przewidziana_kategoria = przyporzadkuj_kategorie(przewidywane)

    return rzeczywista_kategoria, przewidziana_kategoria

import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import seaborn as sns

# Przykładowe dane - zastąp tym odpowiednimi danymi
results = pd.DataFrame({
    'Data': pd.date_range(start='2023-09-01', periods=30),
    'Rzeczywiste wartości (y_test)': y_test_test,
    'Przewidywane wartości (y_pred)': y_pred_test
})

# Dodaj kolumny kategorii i porównania
results['Rzeczywista kategoria'], results['Przewidziana kategoria'] = zip(*results.apply(lambda row: ocen_jakosc_powietrza(row['Rzeczywiste wartości (y_test)'], row['Przewidywane wartości (y_pred)']), axis=1))
results['Zgadza się'] = results['Rzeczywista kategoria'] == results['Przewidziana kategoria']
legend_added = False  # Dodaj legendę tylko raz

# Wyodrębnij unikalne daty
unikalne_daty = results['Data'].unique()


procent_poprawnych = results['Zgadza się'].mean() * 100
procent_poprawnych = round(procent_poprawnych, 2)
print(f"Procent dobrze przewidzianych kategorii (zbiór testowy tydzień): {procent_poprawnych:.2f}%")
procent_poprawnych = str(procent_poprawnych)



plt.figure(figsize=(14, 6))
sns.set_palette("Set2")  # Wybierz zestaw kolorów
for data in unikalne_daty:
    dane_dnia = results[results['Data'] == data]
    color = 'green' if dane_dnia['Zgadza się'].all() else 'red'
    
    if not legend_added:
        
        plt.scatter([data]*len(dane_dnia), dane_dnia['Rzeczywiste wartości (y_test)'],label='Rzeczywiste', color='mediumblue',marker='_')
        plt.scatter([data]*len(dane_dnia), dane_dnia['Przewidywane wartości (y_pred)'], label='Przewidywane',color='darkorange',marker='_')
        legend_added = True

    plt.scatter([data]*len(dane_dnia), dane_dnia['Rzeczywiste wartości (y_test)'], color=color, marker='o',zorder=2)
    plt.scatter([data]*len(dane_dnia), dane_dnia['Przewidywane wartości (y_pred)'],color=color, marker='x',zorder=2)

    progi_jakosci_powietrza = [12, 35, 55]
    for prog in progi_jakosci_powietrza:
        plt.axhline(y=prog, color='gray', linestyle='--')

plt.plot(results['Data'], results['Rzeczywiste wartości (y_test)'], color='mediumblue',alpha=0.3, linestyle='-', zorder=1)
plt.plot(results['Data'], results['Przewidywane wartości (y_pred)'], color='darkorange',alpha=0.3, linestyle='-', zorder=1)


plt.legend(loc='upper right')
plt.title('Porównanie przewidywań na poszczególne dni. Skuteczność: '+procent_poprawnych+'%')
plt.xlabel('Data')
plt.ylabel('Wartości PM2.5')
plt.xticks(ticks=unikalne_daty, labels=[data.strftime('%Y-%m-%d') for data in unikalne_daty], rotation=45, ha='right')
plt.show()



# Przykładowe dane - zastąp tym odpowiednimi danymi
results = pd.DataFrame({
    'Data': pd.date_range(start='2023-09-01', periods=30),
    'Rzeczywiste wartości (y_test)': y_test_test,
    'Przewidywane wartości (y_pred)': y_pred_test_2
})

# Dodaj kolumny kategorii i porównania
results['Rzeczywista kategoria'], results['Przewidziana kategoria'] = zip(*results.apply(lambda row: ocen_jakosc_powietrza(row['Rzeczywiste wartości (y_test)'], row['Przewidywane wartości (y_pred)']), axis=1))
results['Zgadza się'] = results['Rzeczywista kategoria'] == results['Przewidziana kategoria']
legend_added = False  # Dodaj legendę tylko raz

# Wyodrębnij unikalne daty
unikalne_daty = results['Data'].unique()

procent_poprawnych = results['Zgadza się'].mean() * 100
procent_poprawnych = round(procent_poprawnych, 2)
print(f"Procent dobrze przewidzianych kategorii (zbiór testowy tydzień): {procent_poprawnych:.2f}%")
procent_poprawnych = str(procent_poprawnych)


plt.figure(figsize=(14, 6))
sns.set_palette("Set2")  # Wybierz zestaw kolorów
for data in unikalne_daty:
    dane_dnia = results[results['Data'] == data]
    color = 'green' if dane_dnia['Zgadza się'].all() else 'red'
    
    if not legend_added:
        
        plt.scatter([data]*len(dane_dnia), dane_dnia['Rzeczywiste wartości (y_test)'],label='Rzeczywiste', color='mediumblue',marker='_')
        plt.scatter([data]*len(dane_dnia), dane_dnia['Przewidywane wartości (y_pred)'], label='Przewidywane',color='darkorange',marker='_')
        legend_added = True

    plt.scatter([data]*len(dane_dnia), dane_dnia['Rzeczywiste wartości (y_test)'], color=color, marker='o',zorder=2)
    plt.scatter([data]*len(dane_dnia), dane_dnia['Przewidywane wartości (y_pred)'],color=color, marker='x',zorder=2)

    progi_jakosci_powietrza = [12, 35, 55]
    for prog in progi_jakosci_powietrza:
        plt.axhline(y=prog, color='gray', linestyle='--')

plt.plot(results['Data'], results['Rzeczywiste wartości (y_test)'], color='mediumblue',alpha=0.3, linestyle='-', zorder=1)
plt.plot(results['Data'], results['Przewidywane wartości (y_pred)'], color='darkorange',alpha=0.3, linestyle='-', zorder=1)


plt.legend(loc='upper right')
plt.title('Porównanie przewidywań na poszczególne dni. Skuteczność: '+procent_poprawnych+'%')
plt.xlabel('Data')
plt.ylabel('Wartości PM2.5')
plt.xticks(ticks=unikalne_daty, labels=[data.strftime('%Y-%m-%d') for data in unikalne_daty], rotation=45, ha='right')
plt.show()
# Out:
# [I 2024-01-03 18:16:39,367] A new study created in memory with name: no-name-db07f635-e213-4783-916f-cd4760c61625
# [I 2024-01-03 18:16:40,636] Trial 0 finished with value: -0.4513363161981214 and parameters: {'n_estimators': 463, 'max_depth': 1645, 'min_samples_split': 56, 'min_samples_leaf': 41, 'max_features': 0.8254955401934437, 'min_weight_fraction_leaf': 0.4414795353735409}. Best is trial 0 with value: -0.4513363161981214.
# [I 2024-01-03 18:16:40,703] Trial 1 finished with value: -0.41568794687775434 and parameters: {'n_estimators': 43, 'max_depth': 1011, 'min_samples_split': 71, 'min_samples_leaf': 79, 'max_features': 0.26890927724113833, 'min_weight_fraction_leaf': 0.43382647653144374}. Best is trial 1 with value: -0.41568794687775434.
# [I 2024-01-03 18:16:41,387] Trial 2 finished with value: -0.4377220701785618 and parameters: {'n_estimators': 339, 'max_depth': 1702, 'min_samples_split': 36, 'min_samples_leaf': 49, 'max_features': 0.6369556956220441, 'min_weight_fraction_leaf': 0.44298632357911877}. Best is trial 1 with value: -0.41568794687775434.
# [I 2024-01-03 18:16:43,868] Trial 3 finished with value: -0.4473448712235977 and parameters: {'n_estimators': 710, 'max_depth': 1661, 'min_samples_split': 14, 'min_samples_leaf': 50, 'max_features': 0.4854077170840164, 'min_weight_fraction_leaf': 0.11598263749599103}. Best is trial 1 with value: -0.41568794687775434.
# [I 2024-01-03 18:16:45,208] Trial 4 finished with value: -0.5629740462762987 and parameters: {'n_estimators': 488, 'max_depth': 2087, 'min_samples_split': 3, 'min_samples_leaf': 26, 'max_features': 0.9727773544704591, 'min_weight_fraction_leaf': 0.3708872330753465}. Best is trial 1 with value: -0.41568794687775434.
# [I 2024-01-03 18:16:45,798] Trial 5 finished with value: -0.49408215931690935 and parameters: {'n_estimators': 200, 'max_depth': 342, 'min_samples_split': 36, 'min_samples_leaf': 45, 'max_features': 0.5477545537377486, 'min_weight_fraction_leaf': 0.2953976866136255}. Best is trial 1 with value: -0.41568794687775434.
# [I 2024-01-03 18:16:45,979] Trial 6 finished with value: -0.6209118301304899 and parameters: {'n_estimators': 43, 'max_depth': 2139, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': 0.6733671620893051, 'min_weight_fraction_leaf': 0.1926413796510772}. Best is trial 1 with value: -0.41568794687775434.
# [I 2024-01-03 18:16:47,090] Trial 7 finished with value: -0.5174883803662647 and parameters: {'n_estimators': 421, 'max_depth': 791, 'min_samples_split': 37, 'min_samples_leaf': 54, 'max_features': 0.979156859285087, 'min_weight_fraction_leaf': 0.441592739853784}. Best is trial 1 with value: -0.41568794687775434.
# [I 2024-01-03 18:16:47,423] Trial 8 finished with value: -0.8134678837624254 and parameters: {'n_estimators': 56, 'max_depth': 1324, 'min_samples_split': 4, 'min_samples_leaf': 31, 'max_features': 0.9455162631747424, 'min_weight_fraction_leaf': 0.1046070920351827}. Best is trial 1 with value: -0.41568794687775434.
# [I 2024-01-03 18:16:49,368] Trial 9 finished with value: -0.48689169128952026 and parameters: {'n_estimators': 521, 'max_depth': 1017, 'min_samples_split': 4, 'min_samples_leaf': 75, 'max_features': 0.3442571377379512, 'min_weight_fraction_leaf': 0.08988819806833492}. Best is trial 1 with value: -0.41568794687775434.
# [I 2024-01-03 18:16:50,904] Trial 10 finished with value: -0.36575724441175517 and parameters: {'n_estimators': 851, 'max_depth': 66, 'min_samples_split': 94, 'min_samples_leaf': 93, 'max_features': 0.11737228002230762, 'min_weight_fraction_leaf': 0.2945813464575653}. Best is trial 10 with value: -0.36575724441175517.
# [I 2024-01-03 18:16:52,588] Trial 11 finished with value: -0.37088235669820024 and parameters: {'n_estimators': 901, 'max_depth': 161, 'min_samples_split': 94, 'min_samples_leaf': 100, 'max_features': 0.12942970589129998, 'min_weight_fraction_leaf': 0.32059179689289397}. Best is trial 10 with value: -0.36575724441175517.
# [I 2024-01-03 18:16:54,303] Trial 12 finished with value: -0.36531697690263276 and parameters: {'n_estimators': 965, 'max_depth': 58, 'min_samples_split': 94, 'min_samples_leaf': 100, 'max_features': 0.11777741373538357, 'min_weight_fraction_leaf': 0.2996757121597519}. Best is trial 12 with value: -0.36531697690263276.
# [I 2024-01-03 18:16:56,300] Trial 13 finished with value: -0.3613481028368588 and parameters: {'n_estimators': 987, 'max_depth': 516, 'min_samples_split': 98, 'min_samples_leaf': 98, 'max_features': 0.10276026501178542, 'min_weight_fraction_leaf': 0.21565134933138316}. Best is trial 13 with value: -0.3613481028368588.
# [I 2024-01-03 18:16:58,323] Trial 14 finished with value: -0.36191368151046377 and parameters: {'n_estimators': 999, 'max_depth': 511, 'min_samples_split': 73, 'min_samples_leaf': 73, 'max_features': 0.2650741243696833, 'min_weight_fraction_leaf': 0.21057319360119597}. Best is trial 13 with value: -0.3613481028368588.
# [I 2024-01-03 18:17:00,274] Trial 15 finished with value: -0.36542591952283154 and parameters: {'n_estimators': 724, 'max_depth': 518, 'min_samples_split': 75, 'min_samples_leaf': 71, 'max_features': 0.2612748584625411, 'min_weight_fraction_leaf': 0.2012481049767055}. Best is trial 13 with value: -0.3613481028368588.
# [I 2024-01-03 18:17:04,605] Trial 16 finished with value: -0.612369362809219 and parameters: {'n_estimators': 743, 'max_depth': 627, 'min_samples_split': 79, 'min_samples_leaf': 85, 'max_features': 0.3717454654252035, 'min_weight_fraction_leaf': 0.0046233060768446355}. Best is trial 13 with value: -0.3613481028368588.
# [I 2024-01-03 18:17:06,572] Trial 17 finished with value: -0.3475773752449478 and parameters: {'n_estimators': 993, 'max_depth': 794, 'min_samples_split': 63, 'min_samples_leaf': 63, 'max_features': 0.22957851132044504, 'min_weight_fraction_leaf': 0.2242915241969676}. Best is trial 17 with value: -0.3475773752449478.
# [I 2024-01-03 18:17:08,112] Trial 18 finished with value: -0.33842885774553344 and parameters: {'n_estimators': 831, 'max_depth': 866, 'min_samples_split': 48, 'min_samples_leaf': 62, 'max_features': 0.206257733965371, 'min_weight_fraction_leaf': 0.24087299533972067}. Best is trial 18 with value: -0.33842885774553344.
# [I 2024-01-03 18:17:09,291] Trial 19 finished with value: -0.42969486991013484 and parameters: {'n_estimators': 611, 'max_depth': 1291, 'min_samples_split': 54, 'min_samples_leaf': 62, 'max_features': 0.42188726722693815, 'min_weight_fraction_leaf': 0.49767839710015366}. Best is trial 18 with value: -0.33842885774553344.
# [I 2024-01-03 18:17:10,872] Trial 20 finished with value: -0.33966881845697316 and parameters: {'n_estimators': 806, 'max_depth': 993, 'min_samples_split': 63, 'min_samples_leaf': 61, 'max_features': 0.2736660261193281, 'min_weight_fraction_leaf': 0.2442198239348693}. Best is trial 18 with value: -0.33842885774553344.
# [I 2024-01-03 18:17:12,388] Trial 21 finished with value: -0.34799117033327387 and parameters: {'n_estimators': 828, 'max_depth': 910, 'min_samples_split': 60, 'min_samples_leaf': 63, 'max_features': 0.23970617749905077, 'min_weight_fraction_leaf': 0.25067470261312913}. Best is trial 18 with value: -0.33842885774553344.
# [I 2024-01-03 18:17:13,957] Trial 22 finished with value: -0.34812747749499673 and parameters: {'n_estimators': 819, 'max_depth': 1167, 'min_samples_split': 45, 'min_samples_leaf': 62, 'max_features': 0.20974940676155487, 'min_weight_fraction_leaf': 0.24701863724260067}. Best is trial 18 with value: -0.33842885774553344.
# [I 2024-01-03 18:17:15,743] Trial 23 finished with value: -0.4794249077365089 and parameters: {'n_estimators': 648, 'max_depth': 757, 'min_samples_split': 63, 'min_samples_leaf': 38, 'max_features': 0.3457140859287242, 'min_weight_fraction_leaf': 0.16181167289484616}. Best is trial 18 with value: -0.33842885774553344.
# [I 2024-01-03 18:17:17,432] Trial 24 finished with value: -0.3473828963259564 and parameters: {'n_estimators': 890, 'max_depth': 2428, 'min_samples_split': 47, 'min_samples_leaf': 57, 'max_features': 0.20172692805200895, 'min_weight_fraction_leaf': 0.25562165828039185}. Best is trial 18 with value: -0.33842885774553344.
# [I 2024-01-03 18:17:18,988] Trial 25 finished with value: -0.356016948182418 and parameters: {'n_estimators': 895, 'max_depth': 2415, 'min_samples_split': 24, 'min_samples_leaf': 55, 'max_features': 0.17384470886171, 'min_weight_fraction_leaf': 0.2635390300612362}. Best is trial 18 with value: -0.33842885774553344.
# [I 2024-01-03 18:17:20,026] Trial 26 finished with value: -0.39458589360437224 and parameters: {'n_estimators': 618, 'max_depth': 1387, 'min_samples_split': 47, 'min_samples_leaf': 82, 'max_features': 0.3168708608913343, 'min_weight_fraction_leaf': 0.3458016238200295}. Best is trial 18 with value: -0.33842885774553344.
# [I 2024-01-03 18:17:21,529] Trial 27 finished with value: -0.35018306265137467 and parameters: {'n_estimators': 775, 'max_depth': 2494, 'min_samples_split': 22, 'min_samples_leaf': 20, 'max_features': 0.18046818935449807, 'min_weight_fraction_leaf': 0.25528705414217223}. Best is trial 18 with value: -0.33842885774553344.
# [I 2024-01-03 18:17:23,481] Trial 28 finished with value: -0.4782402793896747 and parameters: {'n_estimators': 683, 'max_depth': 1520, 'min_samples_split': 43, 'min_samples_leaf': 69, 'max_features': 0.3974042282090963, 'min_weight_fraction_leaf': 0.16883986256552852}. Best is trial 18 with value: -0.33842885774553344.
# [I 2024-01-03 18:17:24,487] Trial 29 finished with value: -0.3946372525499888 and parameters: {'n_estimators': 562, 'max_depth': 1849, 'min_samples_split': 84, 'min_samples_leaf': 36, 'max_features': 0.17846845761454655, 'min_weight_fraction_leaf': 0.3444680173263755}. Best is trial 18 with value: -0.33842885774553344.
# [I 2024-01-03 18:17:26,316] Trial 30 finished with value: -0.3659825477855694 and parameters: {'n_estimators': 919, 'max_depth': 1128, 'min_samples_split': 53, 'min_samples_leaf': 55, 'max_features': 0.30492012371017857, 'min_weight_fraction_leaf': 0.27930161464960623}. Best is trial 18 with value: -0.33842885774553344.
# [I 2024-01-03 18:17:27,841] Trial 31 finished with value: -0.3377931841605728 and parameters: {'n_estimators': 804, 'max_depth': 779, 'min_samples_split': 60, 'min_samples_leaf': 66, 'max_features': 0.228884939491813, 'min_weight_fraction_leaf': 0.23085454046630968}. Best is trial 31 with value: -0.3377931841605728.
# [I 2024-01-03 18:17:29,319] Trial 32 finished with value: -0.3393242887685397 and parameters: {'n_estimators': 797, 'max_depth': 997, 'min_samples_split': 68, 'min_samples_leaf': 67, 'max_features': 0.29041625795616494, 'min_weight_fraction_leaf': 0.23558586141157856}. Best is trial 31 with value: -0.3377931841605728.
# [I 2024-01-03 18:17:31,001] Trial 33 finished with value: -0.34963069785453293 and parameters: {'n_estimators': 786, 'max_depth': 1007, 'min_samples_split': 68, 'min_samples_leaf': 88, 'max_features': 0.29851644191659177, 'min_weight_fraction_leaf': 0.2255638505527069}. Best is trial 31 with value: -0.3377931841605728.
# [I 2024-01-03 18:17:33,240] Trial 34 finished with value: -0.4744864804225426 and parameters: {'n_estimators': 782, 'max_depth': 905, 'min_samples_split': 58, 'min_samples_leaf': 79, 'max_features': 0.4316923649825315, 'min_weight_fraction_leaf': 0.17507655029627037}. Best is trial 31 with value: -0.3377931841605728.
# [I 2024-01-03 18:17:34,116] Trial 35 finished with value: -0.32914965831612086 and parameters: {'n_estimators': 412, 'max_depth': 650, 'min_samples_split': 68, 'min_samples_leaf': 46, 'max_features': 0.28249254679244323, 'min_weight_fraction_leaf': 0.23179420798728423}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:17:35,020] Trial 36 finished with value: -0.3680410427632381 and parameters: {'n_estimators': 385, 'max_depth': 354, 'min_samples_split': 82, 'min_samples_leaf': 45, 'max_features': 0.33100356922297575, 'min_weight_fraction_leaf': 0.13915139523379527}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:17:35,845] Trial 37 finished with value: -0.4531856615657268 and parameters: {'n_estimators': 276, 'max_depth': 665, 'min_samples_split': 69, 'min_samples_leaf': 48, 'max_features': 0.4784414415424336, 'min_weight_fraction_leaf': 0.19512892347640257}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:17:36,468] Trial 38 finished with value: -0.35487784381277243 and parameters: {'n_estimators': 300, 'max_depth': 390, 'min_samples_split': 87, 'min_samples_leaf': 69, 'max_features': 0.2735195236469192, 'min_weight_fraction_leaf': 0.2791413213683446}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:17:37,409] Trial 39 finished with value: -0.3296467566169434 and parameters: {'n_estimators': 448, 'max_depth': 1180, 'min_samples_split': 28, 'min_samples_leaf': 44, 'max_features': 0.1565231790439756, 'min_weight_fraction_leaf': 0.22859614780894688}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:17:38,607] Trial 40 finished with value: -0.3673838122120767 and parameters: {'n_estimators': 417, 'max_depth': 1495, 'min_samples_split': 29, 'min_samples_leaf': 26, 'max_features': 0.16286946329801197, 'min_weight_fraction_leaf': 0.3198754851091565}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:17:39,774] Trial 41 finished with value: -0.33061634403168405 and parameters: {'n_estimators': 480, 'max_depth': 1201, 'min_samples_split': 40, 'min_samples_leaf': 42, 'max_features': 0.22777500800767966, 'min_weight_fraction_leaf': 0.23974265056019192}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:17:41,061] Trial 42 finished with value: -0.3536802095419094 and parameters: {'n_estimators': 485, 'max_depth': 1123, 'min_samples_split': 39, 'min_samples_leaf': 41, 'max_features': 0.21708877177304575, 'min_weight_fraction_leaf': 0.18913254099861362}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:17:42,260] Trial 43 finished with value: -0.3566891509771608 and parameters: {'n_estimators': 539, 'max_depth': 853, 'min_samples_split': 30, 'min_samples_leaf': 50, 'max_features': 0.15312630228542984, 'min_weight_fraction_leaf': 0.22265166561248473}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:17:42,749] Trial 44 finished with value: -0.3587259334776991 and parameters: {'n_estimators': 215, 'max_depth': 655, 'min_samples_split': 19, 'min_samples_leaf': 32, 'max_features': 0.24002781020299452, 'min_weight_fraction_leaf': 0.27251398312809344}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:17:43,730] Trial 45 finished with value: -0.33353024837221934 and parameters: {'n_estimators': 436, 'max_depth': 1215, 'min_samples_split': 34, 'min_samples_leaf': 43, 'max_features': 0.10073926539118166, 'min_weight_fraction_leaf': 0.23442318287387928}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:17:44,714] Trial 46 finished with value: -0.35894059141009427 and parameters: {'n_estimators': 444, 'max_depth': 1205, 'min_samples_split': 32, 'min_samples_leaf': 42, 'max_features': 0.1424858697177622, 'min_weight_fraction_leaf': 0.20360673924449757}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:17:45,426] Trial 47 finished with value: -0.3636981795966663 and parameters: {'n_estimators': 363, 'max_depth': 1771, 'min_samples_split': 13, 'min_samples_leaf': 22, 'max_features': 0.1259471057552693, 'min_weight_fraction_leaf': 0.2924805226880721}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:17:46,160] Trial 48 finished with value: -0.3590640790725119 and parameters: {'n_estimators': 311, 'max_depth': 1623, 'min_samples_split': 39, 'min_samples_leaf': 32, 'max_features': 0.10156742803978269, 'min_weight_fraction_leaf': 0.2174215025031289}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:17:47,068] Trial 49 finished with value: -0.36070975087410395 and parameters: {'n_estimators': 467, 'max_depth': 1399, 'min_samples_split': 35, 'min_samples_leaf': 8, 'max_features': 0.14712530817210953, 'min_weight_fraction_leaf': 0.27593465338823125}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:17:48,350] Trial 50 finished with value: -0.36284631170307513 and parameters: {'n_estimators': 562, 'max_depth': 1252, 'min_samples_split': 24, 'min_samples_leaf': 46, 'max_features': 0.24683170765327056, 'min_weight_fraction_leaf': 0.14953965799539762}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:17:49,440] Trial 51 finished with value: -0.33164762569537265 and parameters: {'n_estimators': 507, 'max_depth': 1110, 'min_samples_split': 42, 'min_samples_leaf': 52, 'max_features': 0.18882010602617105, 'min_weight_fraction_leaf': 0.23327084841408277}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:17:50,314] Trial 52 finished with value: -0.35781957246360463 and parameters: {'n_estimators': 397, 'max_depth': 1085, 'min_samples_split': 41, 'min_samples_leaf': 38, 'max_features': 0.18552480362312446, 'min_weight_fraction_leaf': 0.18909523394887254}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:17:51,093] Trial 53 finished with value: -0.3320205966737202 and parameters: {'n_estimators': 341, 'max_depth': 1353, 'min_samples_split': 34, 'min_samples_leaf': 50, 'max_features': 0.14354514558523904, 'min_weight_fraction_leaf': 0.22891990737753948}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:17:52,252] Trial 54 finished with value: -0.3581289008778461 and parameters: {'n_estimators': 504, 'max_depth': 1436, 'min_samples_split': 33, 'min_samples_leaf': 52, 'max_features': 0.1078362701146311, 'min_weight_fraction_leaf': 0.2107743595084473}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:17:52,766] Trial 55 finished with value: -0.334444865469675 and parameters: {'n_estimators': 245, 'max_depth': 1599, 'min_samples_split': 50, 'min_samples_leaf': 41, 'max_features': 0.14516133949396604, 'min_weight_fraction_leaf': 0.2315164821294693}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:17:53,052] Trial 56 finished with value: -0.3411794715289309 and parameters: {'n_estimators': 106, 'max_depth': 1316, 'min_samples_split': 27, 'min_samples_leaf': 50, 'max_features': 0.1962267136491383, 'min_weight_fraction_leaf': 0.25709576405522183}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:17:53,799] Trial 57 finished with value: -0.36227567723793563 and parameters: {'n_estimators': 349, 'max_depth': 1200, 'min_samples_split': 15, 'min_samples_leaf': 58, 'max_features': 0.10134614332738962, 'min_weight_fraction_leaf': 0.18527029882765522}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:17:54,787] Trial 58 finished with value: -0.3587602041891409 and parameters: {'n_estimators': 440, 'max_depth': 1865, 'min_samples_split': 38, 'min_samples_leaf': 44, 'max_features': 0.1622800936156922, 'min_weight_fraction_leaf': 0.20782111531474187}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:17:55,938] Trial 59 finished with value: -0.33285019208581224 and parameters: {'n_estimators': 527, 'max_depth': 1065, 'min_samples_split': 35, 'min_samples_leaf': 29, 'max_features': 0.25858060088363904, 'min_weight_fraction_leaf': 0.2427748496338828}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:17:57,100] Trial 60 finished with value: -0.3520514256083469 and parameters: {'n_estimators': 588, 'max_depth': 1092, 'min_samples_split': 43, 'min_samples_leaf': 2, 'max_features': 0.2645247811292555, 'min_weight_fraction_leaf': 0.2652923631208331}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:17:58,166] Trial 61 finished with value: -0.33113810807598143 and parameters: {'n_estimators': 521, 'max_depth': 1370, 'min_samples_split': 35, 'min_samples_leaf': 36, 'max_features': 0.2158585428551355, 'min_weight_fraction_leaf': 0.23606535252049396}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:17:59,194] Trial 62 finished with value: -0.3318136748733853 and parameters: {'n_estimators': 527, 'max_depth': 193, 'min_samples_split': 27, 'min_samples_leaf': 36, 'max_features': 0.22264525324959183, 'min_weight_fraction_leaf': 0.2421494769188397}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:18:00,414] Trial 63 finished with value: -0.3577854027450411 and parameters: {'n_estimators': 479, 'max_depth': 265, 'min_samples_split': 28, 'min_samples_leaf': 37, 'max_features': 0.2075076410113419, 'min_weight_fraction_leaf': 0.20798482999720855}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:18:01,739] Trial 64 finished with value: -0.3478934328857255 and parameters: {'n_estimators': 644, 'max_depth': 190, 'min_samples_split': 19, 'min_samples_leaf': 35, 'max_features': 0.22470020669965876, 'min_weight_fraction_leaf': 0.25296761707087195}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:18:02,629] Trial 65 finished with value: -0.36048293820597554 and parameters: {'n_estimators': 378, 'max_depth': 440, 'min_samples_split': 25, 'min_samples_leaf': 47, 'max_features': 0.18511214879069807, 'min_weight_fraction_leaf': 0.2205342788878911}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:18:03,306] Trial 66 finished with value: -0.36120298914348536 and parameters: {'n_estimators': 323, 'max_depth': 14, 'min_samples_split': 42, 'min_samples_leaf': 53, 'max_features': 0.1362432074982115, 'min_weight_fraction_leaf': 0.30064371568235476}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:18:04,284] Trial 67 finished with value: -0.3314935516387201 and parameters: {'n_estimators': 504, 'max_depth': 1334, 'min_samples_split': 31, 'min_samples_leaf': 25, 'max_features': 0.32513824405222397, 'min_weight_fraction_leaf': 0.24345247021578725}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:18:05,514] Trial 68 finished with value: -0.4132879972001422 and parameters: {'n_estimators': 512, 'max_depth': 1568, 'min_samples_split': 31, 'min_samples_leaf': 17, 'max_features': 0.3414707654014846, 'min_weight_fraction_leaf': 0.24615820071114491}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:18:06,653] Trial 69 finished with value: -0.35175092113159945 and parameters: {'n_estimators': 581, 'max_depth': 1693, 'min_samples_split': 20, 'min_samples_leaf': 23, 'max_features': 0.2912848031771909, 'min_weight_fraction_leaf': 0.26624781027389616}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:18:07,837] Trial 70 finished with value: -0.3587249717948626 and parameters: {'n_estimators': 544, 'max_depth': 1441, 'min_samples_split': 45, 'min_samples_leaf': 28, 'max_features': 0.3163845528580116, 'min_weight_fraction_leaf': 0.17863360510696552}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:18:08,653] Trial 71 finished with value: -0.3323558479879296 and parameters: {'n_estimators': 405, 'max_depth': 1313, 'min_samples_split': 37, 'min_samples_leaf': 34, 'max_features': 0.23235371762929785, 'min_weight_fraction_leaf': 0.23860054189912377}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:18:09,714] Trial 72 finished with value: -0.3566920872527901 and parameters: {'n_estimators': 464, 'max_depth': 1367, 'min_samples_split': 26, 'min_samples_leaf': 40, 'max_features': 0.19993429606313584, 'min_weight_fraction_leaf': 0.19955478004887883}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:18:10,768] Trial 73 finished with value: -0.35409211759861736 and parameters: {'n_estimators': 509, 'max_depth': 1501, 'min_samples_split': 53, 'min_samples_leaf': 59, 'max_features': 0.27770062593923256, 'min_weight_fraction_leaf': 0.22275409113405478}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:18:11,895] Trial 74 finished with value: -0.345888826458584 and parameters: {'n_estimators': 606, 'max_depth': 938, 'min_samples_split': 40, 'min_samples_leaf': 48, 'max_features': 0.24995449143143933, 'min_weight_fraction_leaf': 0.25485602201157304}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:18:12,872] Trial 75 finished with value: -0.36266103198632504 and parameters: {'n_estimators': 453, 'max_depth': 157, 'min_samples_split': 31, 'min_samples_leaf': 17, 'max_features': 0.16586911902322046, 'min_weight_fraction_leaf': 0.2832937322790302}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:18:13,896] Trial 76 finished with value: -0.32998736742462875 and parameters: {'n_estimators': 487, 'max_depth': 1290, 'min_samples_split': 48, 'min_samples_leaf': 40, 'max_features': 0.21167327939951375, 'min_weight_fraction_leaf': 0.2406832338535756}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:18:15,184] Trial 77 finished with value: -0.4344451522083199 and parameters: {'n_estimators': 543, 'max_depth': 1275, 'min_samples_split': 50, 'min_samples_leaf': 39, 'max_features': 0.36467105660434485, 'min_weight_fraction_leaf': 0.26866255761554975}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:18:16,408] Trial 78 finished with value: -0.33672598131961307 and parameters: {'n_estimators': 636, 'max_depth': 728, 'min_samples_split': 56, 'min_samples_leaf': 29, 'max_features': 0.3087039397686018, 'min_weight_fraction_leaf': 0.24347695497403163}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:18:17,827] Trial 79 finished with value: -0.3631252002525085 and parameters: {'n_estimators': 671, 'max_depth': 1178, 'min_samples_split': 47, 'min_samples_leaf': 33, 'max_features': 0.22336479250118862, 'min_weight_fraction_leaf': 0.20012292159565778}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:18:19,144] Trial 80 finished with value: -0.3577292223415429 and parameters: {'n_estimators': 565, 'max_depth': 520, 'min_samples_split': 44, 'min_samples_leaf': 26, 'max_features': 0.2842455063597329, 'min_weight_fraction_leaf': 0.21535756923245175}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:18:20,106] Trial 81 finished with value: -0.33116669607201743 and parameters: {'n_estimators': 482, 'max_depth': 1358, 'min_samples_split': 37, 'min_samples_leaf': 45, 'max_features': 0.18235809976863324, 'min_weight_fraction_leaf': 0.2332967147592154}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:18:21,061] Trial 82 finished with value: -0.3450887587640581 and parameters: {'n_estimators': 491, 'max_depth': 1460, 'min_samples_split': 22, 'min_samples_leaf': 44, 'max_features': 0.18991031174770226, 'min_weight_fraction_leaf': 0.25910258762382327}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:18:22,039] Trial 83 finished with value: -0.33153996687866716 and parameters: {'n_estimators': 415, 'max_depth': 1548, 'min_samples_split': 38, 'min_samples_leaf': 36, 'max_features': 0.2595102105427733, 'min_weight_fraction_leaf': 0.23373180124106566}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:18:23,075] Trial 84 finished with value: -0.33090793792552264 and parameters: {'n_estimators': 425, 'max_depth': 1561, 'min_samples_split': 38, 'min_samples_leaf': 43, 'max_features': 0.2511812050740927, 'min_weight_fraction_leaf': 0.230536507851562}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:18:24,107] Trial 85 finished with value: -0.3561847088157277 and parameters: {'n_estimators': 421, 'max_depth': 1745, 'min_samples_split': 39, 'min_samples_leaf': 46, 'max_features': 0.2388234658634882, 'min_weight_fraction_leaf': 0.1928514311238076}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:18:24,975] Trial 86 finished with value: -0.36192089410252004 and parameters: {'n_estimators': 367, 'max_depth': 1983, 'min_samples_split': 36, 'min_samples_leaf': 42, 'max_features': 0.2762384236953106, 'min_weight_fraction_leaf': 0.21305461534589729}. Best is trial 35 with value: -0.32914965831612086.
# [I 2024-01-03 18:18:25,782] Trial 87 finished with value: -0.32861564690556677 and parameters: {'n_estimators': 403, 'max_depth': 1562, 'min_samples_split': 37, 'min_samples_leaf': 38, 'max_features': 0.26075375364082753, 'min_weight_fraction_leaf': 0.22871805450370927}. Best is trial 87 with value: -0.32861564690556677.
# [I 2024-01-03 18:18:26,796] Trial 88 finished with value: -0.3597614442603905 and parameters: {'n_estimators': 471, 'max_depth': 1627, 'min_samples_split': 30, 'min_samples_leaf': 39, 'max_features': 0.31551163537750937, 'min_weight_fraction_leaf': 0.2864034533996037}. Best is trial 87 with value: -0.32861564690556677.
# [I 2024-01-03 18:18:27,736] Trial 89 finished with value: -0.35406323817156427 and parameters: {'n_estimators': 445, 'max_depth': 1258, 'min_samples_split': 76, 'min_samples_leaf': 31, 'max_features': 0.21156797047014686, 'min_weight_fraction_leaf': 0.2717128888839434}. Best is trial 87 with value: -0.32861564690556677.
# [I 2024-01-03 18:18:28,633] Trial 90 finished with value: -0.34482567037961465 and parameters: {'n_estimators': 389, 'max_depth': 1386, 'min_samples_split': 46, 'min_samples_leaf': 44, 'max_features': 0.24972012463902477, 'min_weight_fraction_leaf': 0.25386877459496726}. Best is trial 87 with value: -0.32861564690556677.
# [I 2024-01-03 18:18:29,501] Trial 91 finished with value: -0.3295803389204286 and parameters: {'n_estimators': 419, 'max_depth': 1520, 'min_samples_split': 37, 'min_samples_leaf': 35, 'max_features': 0.2593605950172884, 'min_weight_fraction_leaf': 0.23221011733942576}. Best is trial 87 with value: -0.32861564690556677.
# [I 2024-01-03 18:18:30,480] Trial 92 finished with value: -0.35557073800192884 and parameters: {'n_estimators': 422, 'max_depth': 1674, 'min_samples_split': 49, 'min_samples_leaf': 40, 'max_features': 0.16773323907836948, 'min_weight_fraction_leaf': 0.22138554119660167}. Best is trial 87 with value: -0.32861564690556677.
# [I 2024-01-03 18:18:31,531] Trial 93 finished with value: -0.3300297846760052 and parameters: {'n_estimators': 469, 'max_depth': 1501, 'min_samples_split': 32, 'min_samples_leaf': 55, 'max_features': 0.28857155062541845, 'min_weight_fraction_leaf': 0.22778150478279863}. Best is trial 87 with value: -0.32861564690556677.
# [I 2024-01-03 18:18:32,649] Trial 94 finished with value: -0.3285512890128408 and parameters: {'n_estimators': 483, 'max_depth': 1787, 'min_samples_split': 36, 'min_samples_leaf': 56, 'max_features': 0.29580076012629375, 'min_weight_fraction_leaf': 0.22642244618037002}. Best is trial 94 with value: -0.3285512890128408.
# [I 2024-01-03 18:18:33,454] Trial 95 finished with value: -0.35968084078418316 and parameters: {'n_estimators': 359, 'max_depth': 1860, 'min_samples_split': 41, 'min_samples_leaf': 55, 'max_features': 0.29221304589001695, 'min_weight_fraction_leaf': 0.20487370642593197}. Best is trial 94 with value: -0.3285512890128408.
# [I 2024-01-03 18:18:34,701] Trial 96 finished with value: -0.4410522612313872 and parameters: {'n_estimators': 435, 'max_depth': 1970, 'min_samples_split': 33, 'min_samples_leaf': 54, 'max_features': 0.3450217986150236, 'min_weight_fraction_leaf': 0.22234491534997386}. Best is trial 94 with value: -0.3285512890128408.
# [I 2024-01-03 18:18:35,594] Trial 97 finished with value: -0.365788746394607 and parameters: {'n_estimators': 391, 'max_depth': 1773, 'min_samples_split': 35, 'min_samples_leaf': 60, 'max_features': 0.3053047880689023, 'min_weight_fraction_leaf': 0.17221866460969576}. Best is trial 94 with value: -0.3285512890128408.
# [I 2024-01-03 18:18:36,449] Trial 98 finished with value: -0.3613693889037739 and parameters: {'n_estimators': 325, 'max_depth': 1564, 'min_samples_split': 90, 'min_samples_leaf': 57, 'max_features': 0.26053812041896457, 'min_weight_fraction_leaf': 0.1834700046737059}. Best is trial 94 with value: -0.3285512890128408.
# [I 2024-01-03 18:18:37,195] Trial 99 finished with value: -0.358548793957296 and parameters: {'n_estimators': 291, 'max_depth': 1486, 'min_samples_split': 33, 'min_samples_leaf': 51, 'max_features': 0.2403949396689502, 'min_weight_fraction_leaf': 0.19756970173420807}. Best is trial 94 with value: -0.3285512890128408.
# [I 2024-01-03 18:18:38,251] Trial 100 finished with value: -0.3588320448321276 and parameters: {'n_estimators': 460, 'max_depth': 1729, 'min_samples_split': 52, 'min_samples_leaf': 48, 'max_features': 0.12712870476191995, 'min_weight_fraction_leaf': 0.213551889942329}. Best is trial 94 with value: -0.3285512890128408.
# [I 2024-01-03 18:18:39,245] Trial 101 finished with value: -0.32786838646062 and parameters: {'n_estimators': 491, 'max_depth': 1410, 'min_samples_split': 37, 'min_samples_leaf': 46, 'max_features': 0.20928483326919606, 'min_weight_fraction_leaf': 0.22804166892243438}. Best is trial 101 with value: -0.32786838646062.
# [I 2024-01-03 18:18:40,281] Trial 102 finished with value: -0.327341832501832 and parameters: {'n_estimators': 481, 'max_depth': 1426, 'min_samples_split': 29, 'min_samples_leaf': 64, 'max_features': 0.21055026352582004, 'min_weight_fraction_leaf': 0.22909820206570067}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:18:41,286] Trial 103 finished with value: -0.3285076205382711 and parameters: {'n_estimators': 491, 'max_depth': 1436, 'min_samples_split': 28, 'min_samples_leaf': 66, 'max_features': 0.2059391884175425, 'min_weight_fraction_leaf': 0.22741851489163423}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:18:42,236] Trial 104 finished with value: -0.33990112560338015 and parameters: {'n_estimators': 484, 'max_depth': 1443, 'min_samples_split': 23, 'min_samples_leaf': 77, 'max_features': 0.20273782291683334, 'min_weight_fraction_leaf': 0.2512389745850631}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:18:43,222] Trial 105 finished with value: -0.3604404050655041 and parameters: {'n_estimators': 456, 'max_depth': 2223, 'min_samples_split': 28, 'min_samples_leaf': 68, 'max_features': 0.2758853792843444, 'min_weight_fraction_leaf': 0.20989826988751664}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:18:44,257] Trial 106 finished with value: -0.34911524573595765 and parameters: {'n_estimators': 541, 'max_depth': 1419, 'min_samples_split': 16, 'min_samples_leaf': 65, 'max_features': 0.15822108247418482, 'min_weight_fraction_leaf': 0.22386616805939033}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:18:44,993] Trial 107 finished with value: -0.348729540872488 and parameters: {'n_estimators': 398, 'max_depth': 1642, 'min_samples_split': 29, 'min_samples_leaf': 64, 'max_features': 0.22020258388912575, 'min_weight_fraction_leaf': 0.26031104482416223}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:18:45,963] Trial 108 finished with value: -0.3543198810061152 and parameters: {'n_estimators': 494, 'max_depth': 1035, 'min_samples_split': 25, 'min_samples_leaf': 73, 'max_features': 0.17473642127988506, 'min_weight_fraction_leaf': 0.18866213925596195}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:18:47,159] Trial 109 finished with value: -0.3426687343780366 and parameters: {'n_estimators': 591, 'max_depth': 1804, 'min_samples_split': 100, 'min_samples_leaf': 61, 'max_features': 0.23515378333750533, 'min_weight_fraction_leaf': 0.2485577753817}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:18:48,189] Trial 110 finished with value: -0.3511779999215279 and parameters: {'n_estimators': 562, 'max_depth': 1241, 'min_samples_split': 43, 'min_samples_leaf': 49, 'max_features': 0.2870245795986512, 'min_weight_fraction_leaf': 0.26278014251955417}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:18:48,968] Trial 111 finished with value: -0.33300497178711375 and parameters: {'n_estimators': 424, 'max_depth': 1516, 'min_samples_split': 32, 'min_samples_leaf': 56, 'max_features': 0.25699649032248645, 'min_weight_fraction_leaf': 0.2348667357150424}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:18:49,928] Trial 112 finished with value: -0.32931788536831674 and parameters: {'n_estimators': 439, 'max_depth': 1600, 'min_samples_split': 65, 'min_samples_leaf': 42, 'max_features': 0.1991410971030096, 'min_weight_fraction_leaf': 0.22940488179499102}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:18:50,992] Trial 113 finished with value: -0.3571385922953929 and parameters: {'n_estimators': 471, 'max_depth': 1596, 'min_samples_split': 64, 'min_samples_leaf': 38, 'max_features': 0.2006791696096673, 'min_weight_fraction_leaf': 0.21725281341484748}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:18:52,005] Trial 114 finished with value: -0.33991076885316707 and parameters: {'n_estimators': 452, 'max_depth': 1147, 'min_samples_split': 71, 'min_samples_leaf': 42, 'max_features': 0.21323206553947044, 'min_weight_fraction_leaf': 0.2445810522943097}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:18:52,842] Trial 115 finished with value: -0.36278990146258483 and parameters: {'n_estimators': 368, 'max_depth': 1949, 'min_samples_split': 60, 'min_samples_leaf': 70, 'max_features': 0.14495431894936733, 'min_weight_fraction_leaf': 0.20346443291374064}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:18:54,401] Trial 116 finished with value: -0.3298648553020953 and parameters: {'n_estimators': 523, 'max_depth': 1690, 'min_samples_split': 66, 'min_samples_leaf': 46, 'max_features': 0.12235849689868714, 'min_weight_fraction_leaf': 0.2268171350544969}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:18:55,639] Trial 117 finished with value: -0.32906811855615015 and parameters: {'n_estimators': 527, 'max_depth': 1688, 'min_samples_split': 66, 'min_samples_leaf': 52, 'max_features': 0.12710319653565938, 'min_weight_fraction_leaf': 0.22875687751821233}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:18:56,821] Trial 118 finished with value: -0.3567884005502142 and parameters: {'n_estimators': 526, 'max_depth': 1711, 'min_samples_split': 64, 'min_samples_leaf': 47, 'max_features': 0.1222431566017863, 'min_weight_fraction_leaf': 0.19390179699327975}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:18:58,048] Trial 119 finished with value: -0.3576991267040075 and parameters: {'n_estimators': 565, 'max_depth': 1813, 'min_samples_split': 67, 'min_samples_leaf': 52, 'max_features': 0.13453545140957507, 'min_weight_fraction_leaf': 0.2142696452477014}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:18:59,070] Trial 120 finished with value: -0.327858642165602 and parameters: {'n_estimators': 501, 'max_depth': 1593, 'min_samples_split': 66, 'min_samples_leaf': 46, 'max_features': 0.12010573983021008, 'min_weight_fraction_leaf': 0.22790075638807084}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:19:00,144] Trial 121 finished with value: -0.32877178031941034 and parameters: {'n_estimators': 502, 'max_depth': 1661, 'min_samples_split': 66, 'min_samples_leaf': 46, 'max_features': 0.16514004956341224, 'min_weight_fraction_leaf': 0.2277490242144511}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:19:01,236] Trial 122 finished with value: -0.3565385319379317 and parameters: {'n_estimators': 510, 'max_depth': 1674, 'min_samples_split': 66, 'min_samples_leaf': 46, 'max_features': 0.16034748266147592, 'min_weight_fraction_leaf': 0.20509754134070254}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:19:02,120] Trial 123 finished with value: -0.34191301252234907 and parameters: {'n_estimators': 439, 'max_depth': 1629, 'min_samples_split': 71, 'min_samples_leaf': 51, 'max_features': 0.12946874162904717, 'min_weight_fraction_leaf': 0.22578818994352692}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:19:03,211] Trial 124 finished with value: -0.34134951338993225 and parameters: {'n_estimators': 529, 'max_depth': 1598, 'min_samples_split': 74, 'min_samples_leaf': 49, 'max_features': 0.10890515786236836, 'min_weight_fraction_leaf': 0.2491021896099643}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:19:04,350] Trial 125 finished with value: -0.3414498215341828 and parameters: {'n_estimators': 552, 'max_depth': 1888, 'min_samples_split': 69, 'min_samples_leaf': 45, 'max_features': 0.15433379651131107, 'min_weight_fraction_leaf': 0.22529041621106308}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:19:05,080] Trial 126 finished with value: -0.33152285797753 and parameters: {'n_estimators': 406, 'max_depth': 1685, 'min_samples_split': 65, 'min_samples_leaf': 53, 'max_features': 0.17889420758431687, 'min_weight_fraction_leaf': 0.23975178846187278}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:19:06,033] Trial 127 finished with value: -0.35584069381089356 and parameters: {'n_estimators': 492, 'max_depth': 1536, 'min_samples_split': 62, 'min_samples_leaf': 58, 'max_features': 0.11832363591482226, 'min_weight_fraction_leaf': 0.21580479314002865}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:19:07,067] Trial 128 finished with value: -0.35440686659921883 and parameters: {'n_estimators': 583, 'max_depth': 1482, 'min_samples_split': 78, 'min_samples_leaf': 66, 'max_features': 0.17566702710585586, 'min_weight_fraction_leaf': 0.26885641068692545}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:19:07,961] Trial 129 finished with value: -0.35735384634774814 and parameters: {'n_estimators': 511, 'max_depth': 1752, 'min_samples_split': 62, 'min_samples_leaf': 47, 'max_features': 0.19371651003759088, 'min_weight_fraction_leaf': 0.2014912605478091}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:19:08,969] Trial 130 finished with value: -0.33307327136788367 and parameters: {'n_estimators': 615, 'max_depth': 1923, 'min_samples_split': 70, 'min_samples_leaf': 42, 'max_features': 0.1434870064958504, 'min_weight_fraction_leaf': 0.23114270184412816}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:19:09,792] Trial 131 finished with value: -0.32980517703742174 and parameters: {'n_estimators': 494, 'max_depth': 1813, 'min_samples_split': 55, 'min_samples_leaf': 38, 'max_features': 0.16375454844844095, 'min_weight_fraction_leaf': 0.23988323584976462}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:19:10,659] Trial 132 finished with value: -0.34255197171942187 and parameters: {'n_estimators': 526, 'max_depth': 1801, 'min_samples_split': 60, 'min_samples_leaf': 35, 'max_features': 0.16272026824661714, 'min_weight_fraction_leaf': 0.2524251898223195}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:19:11,448] Trial 133 finished with value: -0.3337447430217759 and parameters: {'n_estimators': 455, 'max_depth': 2029, 'min_samples_split': 58, 'min_samples_leaf': 44, 'max_features': 0.10016445204832489, 'min_weight_fraction_leaf': 0.23625093914127446}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:19:12,315] Trial 134 finished with value: -0.3528111741481943 and parameters: {'n_estimators': 497, 'max_depth': 1701, 'min_samples_split': 73, 'min_samples_leaf': 37, 'max_features': 0.13634551059266747, 'min_weight_fraction_leaf': 0.22190740699238115}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:19:13,128] Trial 135 finished with value: -0.3580413936353237 and parameters: {'n_estimators': 443, 'max_depth': 1596, 'min_samples_split': 67, 'min_samples_leaf': 40, 'max_features': 0.19173774844294267, 'min_weight_fraction_leaf': 0.21149415078648748}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:19:13,767] Trial 136 finished with value: -0.3408421184437571 and parameters: {'n_estimators': 408, 'max_depth': 1830, 'min_samples_split': 55, 'min_samples_leaf': 43, 'max_features': 0.12707792143446203, 'min_weight_fraction_leaf': 0.25666039499216153}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:19:14,546] Trial 137 finished with value: -0.33234797704296537 and parameters: {'n_estimators': 476, 'max_depth': 1660, 'min_samples_split': 72, 'min_samples_leaf': 63, 'max_features': 0.1735951887066539, 'min_weight_fraction_leaf': 0.24367362574793366}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:19:15,209] Trial 138 finished with value: -0.33287640298236987 and parameters: {'n_estimators': 383, 'max_depth': 1413, 'min_samples_split': 58, 'min_samples_leaf': 33, 'max_features': 0.15048585762082306, 'min_weight_fraction_leaf': 0.23045416533411547}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:19:15,941] Trial 139 finished with value: -0.3568744977363125 and parameters: {'n_estimators': 432, 'max_depth': 1532, 'min_samples_split': 76, 'min_samples_leaf': 46, 'max_features': 0.11917893958211004, 'min_weight_fraction_leaf': 0.19440523098498663}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:19:16,801] Trial 140 finished with value: -0.35782621372540246 and parameters: {'n_estimators': 546, 'max_depth': 1722, 'min_samples_split': 69, 'min_samples_leaf': 50, 'max_features': 0.229729868144857, 'min_weight_fraction_leaf': 0.2769191525963106}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:19:17,627] Trial 141 finished with value: -0.3365488607006568 and parameters: {'n_estimators': 492, 'max_depth': 1302, 'min_samples_split': 61, 'min_samples_leaf': 40, 'max_features': 0.19637850408562618, 'min_weight_fraction_leaf': 0.2459053559171603}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:19:18,506] Trial 142 finished with value: -0.33274577929656735 and parameters: {'n_estimators': 466, 'max_depth': 1466, 'min_samples_split': 65, 'min_samples_leaf': 39, 'max_features': 0.20677864060033097, 'min_weight_fraction_leaf': 0.24041146317576492}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:19:19,574] Trial 143 finished with value: -0.3404755213492061 and parameters: {'n_estimators': 522, 'max_depth': 590, 'min_samples_split': 66, 'min_samples_leaf': 49, 'max_features': 0.16945759450453848, 'min_weight_fraction_leaf': 0.22439298422102325}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:19:20,464] Trial 144 finished with value: -0.34821066898294495 and parameters: {'n_estimators': 493, 'max_depth': 1641, 'min_samples_split': 27, 'min_samples_leaf': 37, 'max_features': 0.2232941770245204, 'min_weight_fraction_leaf': 0.26175221264485654}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:19:21,435] Trial 145 finished with value: -0.357064568340117 and parameters: {'n_estimators': 511, 'max_depth': 1590, 'min_samples_split': 63, 'min_samples_leaf': 42, 'max_features': 0.1515707736467203, 'min_weight_fraction_leaf': 0.21448389543015214}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:19:22,325] Trial 146 finished with value: -0.33156238170773467 and parameters: {'n_estimators': 473, 'max_depth': 1757, 'min_samples_split': 21, 'min_samples_leaf': 44, 'max_features': 0.2445205512041098, 'min_weight_fraction_leaf': 0.23444725758480925}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:19:23,247] Trial 147 finished with value: -0.35861024161662036 and parameters: {'n_estimators': 454, 'max_depth': 1396, 'min_samples_split': 68, 'min_samples_leaf': 47, 'max_features': 0.21011695617161685, 'min_weight_fraction_leaf': 0.18203901389430188}. Best is trial 102 with value: -0.327341832501832.
# [I 2024-01-03 18:19:23,940] Trial 148 finished with value: -0.361928415366904 and parameters: {'n_estimators': 345, 'max_depth': 1534, 'min_samples_split': 58, 'min_samples_leaf': 34, 'max_features': 0.18673689800538304, 'min_weight_fraction_leaf': 0.2092278620405622}. Best is trial 102 with value: -0.327341832501832.
# ...
# [I 2024-01-03 18:30:32,754] Trial 177 finished with value: 0.8184462411268234 and parameters: {'n_estimators': 515, 'max_depth': 900, 'min_samples_split': 51, 'min_samples_leaf': 8, 'max_features': 0.6317494416290907, 'min_weight_fraction_leaf': 0.0009610197937398538}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:30:36,849] Trial 178 finished with value: 0.7939803066419933 and parameters: {'n_estimators': 461, 'max_depth': 1540, 'min_samples_split': 47, 'min_samples_leaf': 5, 'max_features': 0.7112591651876706, 'min_weight_fraction_leaf': 0.018770476053462222}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:30:40,768] Trial 179 finished with value: 0.7994285457175834 and parameters: {'n_estimators': 511, 'max_depth': 1106, 'min_samples_split': 40, 'min_samples_leaf': 12, 'max_features': 0.6513747043337969, 'min_weight_fraction_leaf': 0.011372093347381408}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:30:42,753] Trial 180 finished with value: 0.7626988249615827 and parameters: {'n_estimators': 332, 'max_depth': 882, 'min_samples_split': 54, 'min_samples_leaf': 16, 'max_features': 0.5908799335600325, 'min_weight_fraction_leaf': 0.025802898160848933}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:30:49,010] Trial 181 finished with value: 0.8358509090762202 and parameters: {'n_estimators': 541, 'max_depth': 941, 'min_samples_split': 43, 'min_samples_leaf': 3, 'max_features': 0.618006302865533, 'min_weight_fraction_leaf': 0.0007282746892748047}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:30:55,815] Trial 182 finished with value: 0.8358509090762202 and parameters: {'n_estimators': 541, 'max_depth': 955, 'min_samples_split': 43, 'min_samples_leaf': 3, 'max_features': 0.6187610734669553, 'min_weight_fraction_leaf': 0.0007892027532545771}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:31:00,100] Trial 183 finished with value: 0.8067471599179358 and parameters: {'n_estimators': 543, 'max_depth': 944, 'min_samples_split': 44, 'min_samples_leaf': 3, 'max_features': 0.6143869858647418, 'min_weight_fraction_leaf': 0.010553930538176215}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:31:04,035] Trial 184 finished with value: 0.7704890335089202 and parameters: {'n_estimators': 567, 'max_depth': 1043, 'min_samples_split': 42, 'min_samples_leaf': 7, 'max_features': 0.6020403657323612, 'min_weight_fraction_leaf': 0.01901203930917224}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:31:09,942] Trial 185 finished with value: 0.8289243013898407 and parameters: {'n_estimators': 487, 'max_depth': 1051, 'min_samples_split': 45, 'min_samples_leaf': 5, 'max_features': 0.5631824930883149, 'min_weight_fraction_leaf': 0.0006740520030258702}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:31:16,835] Trial 186 finished with value: 0.8310637963286044 and parameters: {'n_estimators': 602, 'max_depth': 1063, 'min_samples_split': 39, 'min_samples_leaf': 5, 'max_features': 0.5639337039699746, 'min_weight_fraction_leaf': 0.0010001347546167326}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:31:24,642] Trial 187 finished with value: 0.8310563076494512 and parameters: {'n_estimators': 688, 'max_depth': 1169, 'min_samples_split': 38, 'min_samples_leaf': 10, 'max_features': 0.6216676334053796, 'min_weight_fraction_leaf': 4.59195530572894e-05}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:31:26,804] Trial 188 finished with value: 0.58974061526537 and parameters: {'n_estimators': 590, 'max_depth': 1258, 'min_samples_split': 39, 'min_samples_leaf': 10, 'max_features': 0.5753791117017345, 'min_weight_fraction_leaf': 0.08083695744266148}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:31:34,059] Trial 189 finished with value: 0.827900788261793 and parameters: {'n_estimators': 656, 'max_depth': 1182, 'min_samples_split': 41, 'min_samples_leaf': 7, 'max_features': 0.6242898020104609, 'min_weight_fraction_leaf': 0.0007494962616857269}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:31:41,425] Trial 190 finished with value: 0.836300937003709 and parameters: {'n_estimators': 620, 'max_depth': 1150, 'min_samples_split': 43, 'min_samples_leaf': 5, 'max_features': 0.6360703490130619, 'min_weight_fraction_leaf': 0.0003560064563841676}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:31:43,063] Trial 191 finished with value: 0.2162246475422317 and parameters: {'n_estimators': 627, 'max_depth': 1151, 'min_samples_split': 44, 'min_samples_leaf': 5, 'max_features': 0.6427043914210322, 'min_weight_fraction_leaf': 0.18370330752884603}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:31:49,228] Trial 192 finished with value: 0.8099024014542583 and parameters: {'n_estimators': 699, 'max_depth': 1332, 'min_samples_split': 39, 'min_samples_leaf': 1, 'max_features': 0.6232508303458828, 'min_weight_fraction_leaf': 0.008638185117429954}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:31:55,143] Trial 193 finished with value: 0.8288474017030798 and parameters: {'n_estimators': 599, 'max_depth': 1115, 'min_samples_split': 42, 'min_samples_leaf': 9, 'max_features': 0.6609713122450928, 'min_weight_fraction_leaf': 0.0005809240610992333}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:31:59,203] Trial 194 finished with value: 0.7621720605287903 and parameters: {'n_estimators': 672, 'max_depth': 976, 'min_samples_split': 37, 'min_samples_leaf': 7, 'max_features': 0.5866445766696375, 'min_weight_fraction_leaf': 0.021997188208856128}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:32:01,315] Trial 195 finished with value: 0.4527550190396953 and parameters: {'n_estimators': 692, 'max_depth': 1059, 'min_samples_split': 46, 'min_samples_leaf': 4, 'max_features': 0.6069179242236251, 'min_weight_fraction_leaf': 0.10874828762086722}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:32:01,978] Trial 196 finished with value: 0.20544995774807906 and parameters: {'n_estimators': 275, 'max_depth': 1202, 'min_samples_split': 50, 'min_samples_leaf': 11, 'max_features': 0.6352248393259738, 'min_weight_fraction_leaf': 0.2928050724663329}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:32:10,541] Trial 197 finished with value: 0.8420164186373443 and parameters: {'n_estimators': 610, 'max_depth': 994, 'min_samples_split': 44, 'min_samples_leaf': 5, 'max_features': 0.669590219194666, 'min_weight_fraction_leaf': 7.006307350924728e-05}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:32:20,534] Trial 198 finished with value: 0.8403234494961364 and parameters: {'n_estimators': 733, 'max_depth': 1023, 'min_samples_split': 41, 'min_samples_leaf': 8, 'max_features': 0.6725534959520826, 'min_weight_fraction_leaf': 0.00012605972567016586}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:32:26,352] Trial 199 finished with value: 0.8254807399036685 and parameters: {'n_estimators': 602, 'max_depth': 931, 'min_samples_split': 38, 'min_samples_leaf': 7, 'max_features': 0.6699503554302247, 'min_weight_fraction_leaf': 0.013539480772665527}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:32:32,547] Trial 200 finished with value: 0.8091987493574361 and parameters: {'n_estimators': 692, 'max_depth': 1007, 'min_samples_split': 41, 'min_samples_leaf': 5, 'max_features': 0.6531632035246346, 'min_weight_fraction_leaf': 0.00912108771178171}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:32:42,700] Trial 201 finished with value: 0.839708748490046 and parameters: {'n_estimators': 766, 'max_depth': 1131, 'min_samples_split': 43, 'min_samples_leaf': 9, 'max_features': 0.6713045967325539, 'min_weight_fraction_leaf': 5.57014290307565e-05}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:32:52,821] Trial 202 finished with value: 0.8406662714386588 and parameters: {'n_estimators': 740, 'max_depth': 1141, 'min_samples_split': 44, 'min_samples_leaf': 8, 'max_features': 0.6796611761577196, 'min_weight_fraction_leaf': 2.98464952208984e-05}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:33:02,712] Trial 203 finished with value: 0.841510074853238 and parameters: {'n_estimators': 755, 'max_depth': 1009, 'min_samples_split': 44, 'min_samples_leaf': 8, 'max_features': 0.6842066174217137, 'min_weight_fraction_leaf': 5.741514277160498e-05}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:33:09,412] Trial 204 finished with value: 0.7988155493082321 and parameters: {'n_estimators': 757, 'max_depth': 1117, 'min_samples_split': 44, 'min_samples_leaf': 8, 'max_features': 0.6811703971072163, 'min_weight_fraction_leaf': 0.017674814910065735}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:33:16,392] Trial 205 finished with value: 0.8078943349671259 and parameters: {'n_estimators': 713, 'max_depth': 1006, 'min_samples_split': 45, 'min_samples_leaf': 13, 'max_features': 0.6982536906941526, 'min_weight_fraction_leaf': 0.010367257319688525}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:33:26,685] Trial 206 finished with value: 0.8437139684234127 and parameters: {'n_estimators': 800, 'max_depth': 947, 'min_samples_split': 49, 'min_samples_leaf': 8, 'max_features': 0.675113898884878, 'min_weight_fraction_leaf': 0.00014039881517511352}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:33:28,165] Trial 207 finished with value: 0.16286885667335949 and parameters: {'n_estimators': 793, 'max_depth': 948, 'min_samples_split': 49, 'min_samples_leaf': 9, 'max_features': 0.6787846527892824, 'min_weight_fraction_leaf': 0.4177302596048979}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:33:32,837] Trial 208 finished with value: 0.770430814115757 and parameters: {'n_estimators': 790, 'max_depth': 893, 'min_samples_split': 48, 'min_samples_leaf': 1, 'max_features': 0.6658606291165067, 'min_weight_fraction_leaf': 0.02283887597660497}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:33:41,085] Trial 209 finished with value: 0.8106477217899233 and parameters: {'n_estimators': 822, 'max_depth': 991, 'min_samples_split': 46, 'min_samples_leaf': 6, 'max_features': 0.6975335428807792, 'min_weight_fraction_leaf': 0.010975750806913204}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:33:46,579] Trial 210 finished with value: 0.79243207683554 and parameters: {'n_estimators': 730, 'max_depth': 1054, 'min_samples_split': 52, 'min_samples_leaf': 56, 'max_features': 0.7137604402510543, 'min_weight_fraction_leaf': 0.017868770874562456}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:33:58,057] Trial 211 finished with value: 0.841081383301477 and parameters: {'n_estimators': 826, 'max_depth': 917, 'min_samples_split': 43, 'min_samples_leaf': 7, 'max_features': 0.6706624873906285, 'min_weight_fraction_leaf': 0.00038025759946791265}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:34:06,789] Trial 212 finished with value: 0.807658015460865 and parameters: {'n_estimators': 812, 'max_depth': 941, 'min_samples_split': 42, 'min_samples_leaf': 3, 'max_features': 0.6841557150377673, 'min_weight_fraction_leaf': 0.010478687483567638}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:34:16,534] Trial 213 finished with value: 0.828753668714477 and parameters: {'n_estimators': 867, 'max_depth': 846, 'min_samples_split': 43, 'min_samples_leaf': 8, 'max_features': 0.6665503724618304, 'min_weight_fraction_leaf': 0.001008225778866534}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:34:23,643] Trial 214 finished with value: 0.8308842095478456 and parameters: {'n_estimators': 739, 'max_depth': 903, 'min_samples_split': 48, 'min_samples_leaf': 11, 'max_features': 0.6466665478167977, 'min_weight_fraction_leaf': 0.00012673655923074278}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:34:31,714] Trial 215 finished with value: 0.8133165899233156 and parameters: {'n_estimators': 775, 'max_depth': 987, 'min_samples_split': 46, 'min_samples_leaf': 5, 'max_features': 0.6940064463966777, 'min_weight_fraction_leaf': 0.011070088549281537}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:34:37,455] Trial 216 finished with value: 0.7669075416326343 and parameters: {'n_estimators': 767, 'max_depth': 1134, 'min_samples_split': 50, 'min_samples_leaf': 8, 'max_features': 0.6707858569265253, 'min_weight_fraction_leaf': 0.022421729514791777}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:34:40,632] Trial 217 finished with value: 0.5491821222598392 and parameters: {'n_estimators': 830, 'max_depth': 1025, 'min_samples_split': 41, 'min_samples_leaf': 3, 'max_features': 0.6544814171787473, 'min_weight_fraction_leaf': 0.0883885487313812}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:34:48,499] Trial 218 finished with value: 0.7987031728369437 and parameters: {'n_estimators': 721, 'max_depth': 1257, 'min_samples_split': 45, 'min_samples_leaf': 6, 'max_features': 0.7099200482734197, 'min_weight_fraction_leaf': 0.009740780895632005}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:34:53,767] Trial 219 finished with value: 0.7761410094265397 and parameters: {'n_estimators': 746, 'max_depth': 1083, 'min_samples_split': 43, 'min_samples_leaf': 13, 'max_features': 0.684240294345259, 'min_weight_fraction_leaf': 0.02946896953147668}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:34:56,057] Trial 220 finished with value: 0.3206645819420608 and parameters: {'n_estimators': 811, 'max_depth': 876, 'min_samples_split': 48, 'min_samples_leaf': 10, 'max_features': 0.647068434688157, 'min_weight_fraction_leaf': 0.14906573876539428}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:35:03,551] Trial 221 finished with value: 0.8457712209607146 and parameters: {'n_estimators': 551, 'max_depth': 947, 'min_samples_split': 44, 'min_samples_leaf': 7, 'max_features': 0.6674262021070765, 'min_weight_fraction_leaf': 0.00026651668607784103}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:35:12,794] Trial 222 finished with value: 0.8044880705443042 and parameters: {'n_estimators': 838, 'max_depth': 942, 'min_samples_split': 46, 'min_samples_leaf': 4, 'max_features': 0.6709062973880369, 'min_weight_fraction_leaf': 0.008925937381009563}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:35:23,013] Trial 223 finished with value: 0.841707385810159 and parameters: {'n_estimators': 785, 'max_depth': 986, 'min_samples_split': 43, 'min_samples_leaf': 7, 'max_features': 0.6934419324301382, 'min_weight_fraction_leaf': 0.0002687664261769533}. Best is trial 124 with value: 0.8532059309093576.
# [I 2024-01-03 18:35:29,737] Trial 224 finished with value: 0.8089012799966233 and parameters: {'n_estimators': 783, 'max_depth': 911, 'min_samples_split': 43, 'min_samples_leaf': 7, 'max_features': 0.694964154061637, 'min_weight_fraction_leaf': 0.01708744831470226}. Best is trial 124 with value: 0.8532059309093576.
# Best Parameters: {'n_estimators': 477, 'max_depth': 2103, 'min_samples_split': 44, 'min_samples_leaf': 1, 'max_features': 0.6881120987893243, 'min_weight_fraction_leaf': 0.0003075974539205805}
# Średni błąd kwadratowy (MSE): 96.70172050636756
# Procentowa zgodność: 84.65%
# Średni błąd kwadratowy (MSE): 25.830698283359155
# r2 score: 23.21%
# Procent dobrze przewidzianych kategorii (zbiór testowy tydzień): 70.00%
# Procent dobrze przewidzianych kategorii (zbiór testowy tydzień): 70.00%
