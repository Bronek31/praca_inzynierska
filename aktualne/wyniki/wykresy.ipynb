# %%
ElasicNet_r2 = 82.7 
ElasicNet_mse = 108.96663536057282

LinearRegression_r2 = 82.01
LinearRegression_mse = 113.30088155894086

Lasso_r2 = 82.52
Lasso_mse = 110.12416195052958

Ridge_r2 = 82.70
Ridge_mse = 108.9651026228981

DecisionTree_r2 = 93.25
DecisionTree_mse = 42.548277416786604

GBR_r2 = 94.96
GBR_mse = 31.724717876947977

knn_r2 = 80.17
knn_mse = 124.89435661750007

NeuralNetwork_r2 = 95.15
NeuralNetwork_mse = 30.539041240123854

RandomForest_r2 = 93.98
RandomForest_mse = 37.90454988982884

SVR_r2 = 83.72
SVR_mse = 102.5713712088652

# %%
import matplotlib.pyplot as plt
import numpy as np

modele = ["Regresja liniowa", "Regresja grzbietowa", "Regresja lasso", "Regresja sieci elastycznej", "Metoda K najbliższych sąsiadów", "Metoda wektorów nośnych", "Drzewo decyzyjne", "Gradient Boosting Regression", "Las losowy", "Sieć neuronowa"]
rok = [63.33, 70, 70, 70, 70, 70, 66.67, 70, 70, 90]
tydzien = [66.67, 66.67, 66.67, 70, 80, 76.67, 73.33, 70, 70, 90]
rok3 = [70, 66.67, 66.67, 70, 73.33, 70, 63.33, 70, 70, 86.67]
tydzien3 = [70, 70, 70, 70, 73.33, 86.67, 80, 70, 70, 86.67]

bar_height = 0.2
index = np.arange(len(modele))

plt.figure(figsize=(14, 8))

plt.barh(index, rok, height=bar_height, label='Rok', color='#3498db', zorder=3)
plt.barh(index + bar_height, tydzien, height=bar_height, label='Tydzień', color='#2ecc71', zorder=3)
plt.barh(index + 2 * bar_height, rok3, height=bar_height, label='Ostatnie 4 lata (Rok)', color='#e74c3c', zorder=3)
plt.barh(index + 3 * bar_height, tydzien3, height=bar_height, label='Ostatnie 4 lata (Tydzień)', color='#8e44ad', zorder=3)

plt.ylabel('Modele')
plt.xlabel('Wartości')
plt.title('Porównanie r2 dla różnych modeli i zestawów danych')
plt.yticks(index + 1.5 * bar_height, modele, rotation=0, ha='right')
plt.legend()

# Dodaj grid pod słupkami
plt.grid(axis='x', linestyle='--', alpha=0.7, zorder=1)

# Dodaj etykiety osi x co 5
plt.xticks(np.arange(0, 101, 5))

plt.show()
