# %%
ElasicNet_r2 = 82.7 
ElasicNet_mse = 108.96663536057282

LinearRegression_r2 = 82.01
LinearRegression_mse = 113.30088155894086

Lasso_r2 = 82.52
Lasso_mse = 110.12416195052958

Ridge_r2 = 82.70
Ridge_mse = 108.9651026228981

DecisionTree_r2 = 93.25
DecisionTree_mse = 42.548277416786604

GBR_r2 = 94.96
GBR_mse = 31.724717876947977

knn_r2 = 80.17
knn_mse = 124.89435661750007

NeuralNetwork_r2 = 95.15
NeuralNetwork_mse = 30.539041240123854

RandomForest_r2 = 93.98
RandomForest_mse = 37.90454988982884

SVR_r2 = 83.72
SVR_mse = 102.5713712088652

# %%
import matplotlib.pyplot as plt

modele = ["ElasticNet", "LinearRegression", "Lasso", "Ridge", "DecisionTree", "GBR", "KNN", "NeuralNetwork", "RandomForest", "SVR"]
r2 = [82.7, 82.01, 82.52, 82.7, 93.25, 94.96, 80.17, 95.15, 93.98, 83.72]
mse = [108.97, 113.30, 110.12, 108.97, 42.55, 31.72, 124.89, 30.54, 37.90, 102.57]

modele_r2, r2 = zip(*sorted(zip(modele, r2), key=lambda x: x[1]))

plt.figure(figsize=(12, 6))
plt.barh(modele_r2, r2, color='blue', label='R-squared (r2)')
plt.xlabel('Wartości')
plt.title('Porównanie r2 i mse dla różnych modeli')
plt.legend()

plt.xlim(60, 100)

plt.show()

# %%
modele = ["ElasticNet", "LinearRegression", "Lasso", "Ridge", "DecisionTree", "GBR", "NeuralNetwork", "RandomForest"]
r2 = [82.7, 82.01, 82.52, 82.7, 93.25, 94.96,  95.15, 93.98]
mse = [108.97, 113.30, 110.12, 108.97, 42.55, 31.72,  30.54, 37.90]

modele_r2, r2 = zip(*sorted(zip(modele, r2), key=lambda x: x[1]))

plt.figure(figsize=(12, 6))
plt.barh(modele_r2, r2, color='skyblue', label='R-squared (r2)')
plt.xlabel('Skuteczność w %')
plt.title('Wyniki działania modeli')
plt.legend()

plt.xlim(60, 100)

plt.show()
